# %%
# p.167 Chapter6 学習に関するテクニック
class SGD:
    def __init__(self, lr=0.01):
        self.lr = lr
        
    def update(self, params, grads):
        for key in params.keys():
            params[key] -= self.lr * grads[key]

# %%
# network = TwoLayerNet(...)
# optimizer ~ SGD()

# for i in range(10000):
# ...
#     x_batch, t_batch = get_mini_batch(...) # ミニバッチ
#     grads = network.gradient(x_batch, t_batch)
#     params = network.params
#     optimizer.update(params, grads)
# ...

# %%
# p.170 6.1.4 Momentum
class Momentum:
    def __init__(self, lr=0.01, momentum=0.9):
        self.lr = lr
        self.momentum = momentum
        self.v = None
    
    def update(self, params, grads):
        if self.v is None:
            self.v = {}
            for key, val in params.items():
                self.v[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.v[key] = self.momentum*self.v[key] - self.lr*grads[key]
            params[key] += self.v[key]

# %%
# p.173 6.1.5 AdaGrad
class AdaGrad:
    def __init__(self, lr=0.01):
        self.lr = lr
        self.h = None
        
    def update(self, params, grads):
        if self.h is None:
            self.h = {}
            for key, val in params.items():
                self.h[key] = np.zeros_like(val)
                
        for key in params.keys():
            self.h[key] += grads[key] * grads[key]
            params[key] -= self.lr * grads[key] / (np.sqrt(self.h[key]) + 1e-7)

# %%
class Adam:
    
    def __init__(self, lr=0.001, beta1=0.9, beta2=0.999):
        self.lr = lr
        self.beta1 = beta1
        self.beta2 = beta2
        self.iter = 0
        self.m = None
        self.v = None
        
    def update(self,params, grads):
        if self.m is None:
            self.m, self.v = {}, {}
            for key, val in params.items():
                self.m[key] = np.zeros_like(val)
                self.v[key] = np.zeros_like(val)
                
        self.iter += 1
        lr_t = self.lr * np.sqrt(1.0 - self.beta2**self.iter) / (1.0 - self.beta1**self.iter)
        
        for key in params.keys():
            self.m[key] += (1 - self.beta1) * (grads[key] - self.m[key])
            self.v[key] += (1 - self.beta2) * (grads[key]**2 - self.v[key])
            
            params[key] -= lr_t * self.m[key] / (np.sqrt(self.v[key]) + 1e-7)

# %%
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
# %matplotlib inline

def f(x, y):
    return x**2 / 20.0 + y**2

def df(x, y):
    return x / 10.0, 2.0*y

init_pos = (-7.0, 2.0)
params = {}
params['x'], params['y'] = init_pos[0], init_pos[1]
grads = {}
grads['x'], grads['y'] = 0, 0

optimizers = OrderedDict()
optimizers["SGD"] = SGD(lr=0.95)
optimizers["Momentum"] = Momentum(lr=0.1)
optimizers["AdaGrad"] = AdaGrad(lr=1.5)
optimizers["Adam"] = Adam(lr=0.3)

idx = 1

for key in optimizers:
    optimizer = optimizers[key]
    x_history = []
    y_history = []
    params['x'], params['y'] = init_pos[0], init_pos[1]
    
    for i in range(30):
        x_history.append(params['x'])
        y_history.append(params['y'])
        
        grads['x'], grads['y'] = df(params['x'], params['y'])
        optimizer.update(params, grads)
        
    x = np.arange(-10, 10, 0.01)
    y = np.arange(-5, 5, 0.01)
    
    X, Y = np.meshgrid(x, y)
    Z = f(X, Y)
    
    # 等高線
    mask = Z > 7
    Z[mask] = 0
    
    # plot
    plt.subplot(2, 2, idx)
    idx += 1
    plt.plot(x_history, y_history, 'o-', color="red")
    plt.contour(X, Y, Z)
    plt.ylim(-10, 10)
    plt.xlim,(-10, 10)
    plt.plot(0, 0, '+')
    
    plt.title(key)
    plt.xlabel("x")
    plt.ylabel("y")
    
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def ReLU(x):
    return np.maximum(0, x)

def tanh(x):
    return np.tanh(x)

input_data = np.random.randn(1000, 100) # 1,000個のデータ
node_num = 100 # 各隠れ層のノード(ニューロン)の数
hidden_layer_size = 5 # 隠れ層が5層
activations = {} # ここにアクティベーションの結果を格納する

x = input_data

for i in range(hidden_layer_size):
    if i != 0:
        x = activations[i-1]
        
    # 初期値
    #w = np.random.randn(node_num, node_num) * 1
    #w = np.random.randn(node_num, node_num) * 0.01
    w = np.random.randn(node_num, node_num) / np.sqrt(node_num)
    #w = np.random.randn(node_num, node_num) * np.sqrt(1.0 / node_num)
    #w = np.random.randn(node_num, node_num) * np.sqrt(2.0 / node_num)
    
    a = np.dot(x, w)
    
    # 活性化関数
    # z = sigmoid(a)
    # z = ReLU(a)
    z = tanh(a)
    
    activations[i] = z
    
# ヒストグラムを描画
for i, a in activations.items():
    plt.subplot(1, len(activations), i+1)
    plt.title(str(i+1) + "-layer")
    if i != 0: plt.yticks([], [])
    # plt.xlim(0.1, 1)
    # plt.ylim(0, 7000)
    plt.hist(a.flatten(), 30, range=(0,1))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mnist import load_mnist
from util import smooth_curve
from multi_layer_net import MultiLayerNet

# %%
# MNISTデータの読み込み
(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

train_size = x_train.shape[0]
batch_size = 128
max_iterations = 2000

# %%
# 実験の設定
weight_init_types = {'std=0.01': 0.01, 'Xavier': 'sigmoid', 'He': 'relu'}
optimizer = SGD(lr=0.01)

networks = {}
train_loss = {}
for key, weight_type in weight_init_types.items():
    networks[key] = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100],
                                  output_size=10, weight_init_std=weight_type)
    train_loss[key] = []

# %%
# 訓練の開始
for i in range(max_iterations):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    for key in weight_init_types.keys():
        grads = networks[key].gradient(x_batch, t_batch)
        optimizer.update(networks[key].params, grads)
    
        loss = networks[key].loss(x_batch, t_batch)
        train_loss[key].append(loss)
    
    if i % 100 == 0:
        print("===========" + "iteration:" + str(i) + "===========")
        for key in weight_init_types.keys():
            loss = networks[key].loss(x_batch, t_batch)
            print(key + ":" + str(loss))
            
# グラフの描画
markers = {'std=0.01': "o", 'Xavier': 's', 'He': 'D'}
x = np.arange(max_iterations)
for key in weight_init_types.keys():
    plt.plot(x, smooth_curve(train_loss[key]), marker=markers[key], markevery=100, label=key)    
plt.xlabel("iterations")
plt.ylabel("loss")
plt.ylim(0, 2.5)
plt.legend()
plt.show()
# Out:
# ===========iteration:0===========
# std=0.01:2.3025464708453107
# Xavier:2.314579731239008
# He:2.485559084388829
# ===========iteration:100===========
# std=0.01:2.3028527244437997
# Xavier:2.254768065019589
# He:1.4862807949981187
# ===========iteration:200===========
# std=0.01:2.3039275596349995
# Xavier:2.180192944885028
# He:0.7306462005525187
# ===========iteration:300===========
# std=0.01:2.300760788414798
# Xavier:1.941011921538132
# He:0.5090911827604768
# ===========iteration:400===========
# std=0.01:2.29989722282723
# Xavier:1.3635600384871223
# He:0.4125845458700239
# ===========iteration:500===========
# std=0.01:2.304928454064266
# Xavier:0.9825516135190698
# He:0.3795631583808048
# ===========iteration:600===========
# std=0.01:2.303678329465381
# Xavier:0.8799567091221123
# He:0.5321735924780036
# ===========iteration:700===========
# std=0.01:2.305165368588363
# Xavier:0.6703130420466374
# He:0.3915402195973484
# ===========iteration:800===========
# std=0.01:2.300022201408522
# Xavier:0.5659579823534945
# He:0.3760073705714868
# ===========iteration:900===========
# std=0.01:2.3014822206168963
# Xavier:0.43073813258504184
# He:0.2440082235526322
# ===========iteration:1000===========
# std=0.01:2.2964548585121562
# Xavier:0.42792197814306715
# He:0.30010876428870686
# ===========iteration:1100===========
# std=0.01:2.3019756324544467
# Xavier:0.36694134681578355
# He:0.26611672933273967
# ===========iteration:1200===========
# std=0.01:2.2972085859614326
# Xavier:0.33307845848996825
# He:0.23659768717370583
# ===========iteration:1300===========
# std=0.01:2.307618938533972
# Xavier:0.3100414988801396
# He:0.22392702041642706
# ===========iteration:1400===========
# std=0.01:2.307474191711135
# Xavier:0.42638404412951547
# He:0.25542682574855324
# ===========iteration:1500===========
# std=0.01:2.3027784850188366
# Xavier:0.3248298997172805
# He:0.27484152603567713
# ===========iteration:1600===========
# std=0.01:2.3016738413957283
# Xavier:0.23060137543310458
# He:0.16273341894201093
# ===========iteration:1700===========
# std=0.01:2.3001621443023943
# Xavier:0.3296455357818612
# He:0.2029877135437706
# ===========iteration:1800===========
# std=0.01:2.2985482350622757
# Xavier:0.2180426830729265
# He:0.18122848877107112
# ===========iteration:1900===========
# std=0.01:2.2944445485549974
# Xavier:0.2655317486352657
# He:0.20129717526482607

# %%
import numpy as np
import matplotlib.pyplot as plt
from mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 学習データを削減
x_train = x_train[:1000]
t_train = t_train[:1000]

max_epochs = 20
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01

def __train(weight_init_std):
    bn_network = MultiLayerNetExtend(input_size=784,
                                    hidden_size_list=[100, 100, 100, 100],
                                    output_size=10,
                                    weight_init_std=weight_init_std,
                                    use_batchnorm=True)
    network = MultiLayerNetExtend(input_size=784,
                                 hidden_size_list=[100, 100, 100, 100],
                                 output_size=10,
                                 weight_init_std=weight_init_std)
    optimizer = SGD(lr=learning_rate)
    
    train_acc_list = []
    bn_train_acc_list = []
    
    iter_per_epoch = max(train_size / batch_size, 1)
    epoch_cnt = 0
    
    for i in range(1000000000):
        batch_mask = np.random.choice(train_size, batch_size)
        x_batch = x_train[batch_mask]
        t_batch = t_train[batch_mask]
        
        for _network in (bn_network, network):
            grads = _network.gradient(x_batch, t_batch)
            optimizer.update(_network.params, grads)
            
        if i % iter_per_epoch == 0:
            train_acc = network.accuracy(x_train, t_train)
            bn_train_acc = bn_network.accuracy(x_train, t_train)
            train_acc_list.append(train_acc)
            bn_train_acc_list.append(bn_train_acc)
            
            print("epoch:" + str(epoch_cnt) + " | " + str(train_acc) + " - " + str(bn_train_acc))
            
            epoch_cnt += 1
            if epoch_cnt >= max_epochs:
                break
                
    return train_acc_list, bn_train_acc_list

# グラフの描画
weight_scale_list = np.logspace(0, -4, num=16)
x = np.arange(max_epochs)

for i, w in enumerate(weight_scale_list):
    print( "============== " + str(i+1) + "/16" + " ==============")
    train_acc_list, bn_train_acc_list = __train(w)
    
    plt.subplot(4, 4, i+1)
    plt.title("W:" + str(w))
    
    if i == 15:
        plt.plot(x, bn_train_acc_list, label='Batch Normalization', markevery=2)
        plt.plot(x, train_acc_list, linestyle = "--",
                label='Normal(without BatchNorm)', markevery=2)
    else:
        plt.plot(x, bn_train_acc_list, markevery=2)
        plt.plot(x, train_acc_list, linestyle="--", markevery=2)
        
    plt.ylim(0, 1.0)
    
    if i % 4:
        plt.yticks([])
    else:
        plt.ylabel("accuracy")
    if i < 12:
        plt.xticks([])
    else:
        plt.xlabel("epochs")
    plt.legend(loc='lower right')

plt.show()
# Out:
# ============== 1/16 ==============
# epoch:0 | 0.093 - 0.108
# epoch:1 | 0.097 - 0.106
# /Users/nagahamanil/Desktop/deep-learning-from-zero/Chapter6/multi_layer_net_extend.py:101: RuntimeWarning: overflow encountered in square
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /Users/nagahamanil/Desktop/deep-learning-from-zero/Chapter6/multi_layer_net_extend.py:101: RuntimeWarning: invalid value encountered in double_scalars
#   weight_decay += 0.5 * self.weight_decay_lambda * np.sum(W**2)
# /Users/nagahamanil/Desktop/deep-learning-from-zero/Chapter6/functions.py:34: RuntimeWarning: invalid value encountered in subtract
#   x = x - np.max(x, axis=0)
# /Users/nagahamanil/Desktop/deep-learning-from-zero/Chapter6/layers.py:12: RuntimeWarning: invalid value encountered in less_equal
#   self.mask = (x <= 0)
# epoch:2 | 0.097 - 0.097
# epoch:3 | 0.097 - 0.099
# epoch:4 | 0.097 - 0.116
# epoch:5 | 0.097 - 0.135
# epoch:6 | 0.097 - 0.153
# epoch:7 | 0.097 - 0.167
# epoch:8 | 0.097 - 0.187
# epoch:9 | 0.097 - 0.19
# epoch:10 | 0.097 - 0.227
# epoch:11 | 0.097 - 0.241
# epoch:12 | 0.097 - 0.27
# epoch:13 | 0.097 - 0.279
# epoch:14 | 0.097 - 0.301
# epoch:15 | 0.097 - 0.321
# epoch:16 | 0.097 - 0.331
# epoch:17 | 0.097 - 0.349
# epoch:18 | 0.097 - 0.359
# No handles with labels found to put in legend.
# epoch:19 | 0.097 - 0.374
# ============== 2/16 ==============
# epoch:0 | 0.103 - 0.104
# epoch:1 | 0.159 - 0.124
# epoch:2 | 0.185 - 0.14
# epoch:3 | 0.239 - 0.152
# epoch:4 | 0.258 - 0.169
# epoch:5 | 0.289 - 0.192
# epoch:6 | 0.303 - 0.221
# epoch:7 | 0.306 - 0.25
# epoch:8 | 0.33 - 0.28
# epoch:9 | 0.331 - 0.306
# epoch:10 | 0.379 - 0.331
# epoch:11 | 0.379 - 0.367
# epoch:12 | 0.415 - 0.377
# epoch:13 | 0.411 - 0.397
# epoch:14 | 0.419 - 0.418
# epoch:15 | 0.433 - 0.439
# epoch:16 | 0.439 - 0.45
# epoch:17 | 0.453 - 0.473
# epoch:18 | 0.465 - 0.482
# epoch:19 | 0.456 - 0.491
# No handles with labels found to put in legend.
# ============== 3/16 ==============
# epoch:0 | 0.103 - 0.091
# epoch:1 | 0.445 - 0.094
# epoch:2 | 0.551 - 0.101
# epoch:3 | 0.679 - 0.132
# epoch:4 | 0.757 - 0.166
# epoch:5 | 0.803 - 0.212
# epoch:6 | 0.837 - 0.251
# epoch:7 | 0.873 - 0.292
# epoch:8 | 0.893 - 0.339
# epoch:9 | 0.919 - 0.366
# epoch:10 | 0.935 - 0.398
# epoch:11 | 0.94 - 0.422
# epoch:12 | 0.951 - 0.456
# epoch:13 | 0.97 - 0.474
# epoch:14 | 0.969 - 0.505
# epoch:15 | 0.976 - 0.526
# epoch:16 | 0.975 - 0.546
# epoch:17 | 0.983 - 0.558
# epoch:18 | 0.986 - 0.575
# No handles with labels found to put in legend.
# epoch:19 | 0.991 - 0.589
# ============== 4/16 ==============
# epoch:0 | 0.092 - 0.073
# epoch:1 | 0.207 - 0.098
# epoch:2 | 0.33 - 0.155
# epoch:3 | 0.432 - 0.233
# epoch:4 | 0.51 - 0.305
# epoch:5 | 0.582 - 0.376
# epoch:6 | 0.629 - 0.43
# epoch:7 | 0.664 - 0.474
# epoch:8 | 0.691 - 0.515
# epoch:9 | 0.719 - 0.545
# epoch:10 | 0.732 - 0.571
# epoch:11 | 0.758 - 0.603
# epoch:12 | 0.78 - 0.623
# epoch:13 | 0.805 - 0.654
# epoch:14 | 0.808 - 0.673
# epoch:15 | 0.819 - 0.686
# epoch:16 | 0.835 - 0.703
# epoch:17 | 0.843 - 0.722
# No handles with labels found to put in legend.
# epoch:18 | 0.848 - 0.726
# epoch:19 | 0.857 - 0.748
# ============== 5/16 ==============
# epoch:0 | 0.096 - 0.136
# epoch:1 | 0.109 - 0.173
# epoch:2 | 0.116 - 0.313
# epoch:3 | 0.13 - 0.461
# epoch:4 | 0.138 - 0.557
# epoch:5 | 0.145 - 0.622
# epoch:6 | 0.161 - 0.671
# epoch:7 | 0.175 - 0.699
# epoch:8 | 0.195 - 0.73
# epoch:9 | 0.213 - 0.756
# epoch:10 | 0.227 - 0.775
# epoch:11 | 0.243 - 0.796
# epoch:12 | 0.249 - 0.807
# epoch:13 | 0.272 - 0.82
# epoch:14 | 0.279 - 0.84
# epoch:15 | 0.294 - 0.847
# epoch:16 | 0.296 - 0.857
# epoch:17 | 0.309 - 0.865
# epoch:18 | 0.308 - 0.871
# No handles with labels found to put in legend.
# epoch:19 | 0.315 - 0.877
# ============== 6/16 ==============
# epoch:0 | 0.096 - 0.094
# epoch:1 | 0.101 - 0.244
# epoch:2 | 0.102 - 0.444
# epoch:3 | 0.107 - 0.555
# epoch:4 | 0.11 - 0.634
# epoch:5 | 0.13 - 0.7
# epoch:6 | 0.129 - 0.736
# epoch:7 | 0.117 - 0.764
# epoch:8 | 0.119 - 0.789
# epoch:9 | 0.119 - 0.803
# epoch:10 | 0.118 - 0.816
# epoch:11 | 0.12 - 0.833
# epoch:12 | 0.119 - 0.852
# epoch:13 | 0.119 - 0.866
# epoch:14 | 0.12 - 0.874
# epoch:15 | 0.118 - 0.879
# epoch:16 | 0.118 - 0.89
# epoch:17 | 0.118 - 0.903
# epoch:18 | 0.118 - 0.91
# epoch:19 | 0.117 - 0.919
# No handles with labels found to put in legend.
# ============== 7/16 ==============
# epoch:0 | 0.087 - 0.107
# epoch:1 | 0.094 - 0.322
# epoch:2 | 0.116 - 0.57
# epoch:3 | 0.116 - 0.671
# epoch:4 | 0.175 - 0.731
# epoch:5 | 0.117 - 0.781
# epoch:6 | 0.117 - 0.81
# epoch:7 | 0.117 - 0.835
# epoch:8 | 0.117 - 0.856
# epoch:9 | 0.117 - 0.868
# epoch:10 | 0.191 - 0.891
# epoch:11 | 0.116 - 0.918
# epoch:12 | 0.116 - 0.923
# epoch:13 | 0.12 - 0.937
# epoch:14 | 0.116 - 0.947
# epoch:15 | 0.116 - 0.95
# epoch:16 | 0.116 - 0.953
# epoch:17 | 0.116 - 0.969
# epoch:18 | 0.116 - 0.975
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.975
# ============== 8/16 ==============
# epoch:0 | 0.097 - 0.082
# epoch:1 | 0.117 - 0.55
# epoch:2 | 0.117 - 0.655
# epoch:3 | 0.117 - 0.71
# epoch:4 | 0.117 - 0.769
# epoch:5 | 0.117 - 0.807
# epoch:6 | 0.117 - 0.847
# epoch:7 | 0.117 - 0.874
# epoch:8 | 0.117 - 0.906
# epoch:9 | 0.117 - 0.929
# epoch:10 | 0.117 - 0.959
# epoch:11 | 0.117 - 0.964
# epoch:12 | 0.117 - 0.976
# epoch:13 | 0.117 - 0.987
# epoch:14 | 0.117 - 0.989
# epoch:15 | 0.117 - 0.994
# epoch:16 | 0.117 - 0.995
# epoch:17 | 0.117 - 0.999
# epoch:18 | 0.117 - 0.999
# epoch:19 | 0.117 - 0.999
# No handles with labels found to put in legend.
# ============== 9/16 ==============
# epoch:0 | 0.093 - 0.148
# epoch:1 | 0.116 - 0.564
# epoch:2 | 0.116 - 0.757
# epoch:3 | 0.117 - 0.857
# epoch:4 | 0.117 - 0.909
# epoch:5 | 0.117 - 0.945
# epoch:6 | 0.117 - 0.962
# epoch:7 | 0.117 - 0.971
# epoch:8 | 0.117 - 0.976
# epoch:9 | 0.117 - 0.985
# epoch:10 | 0.117 - 0.988
# epoch:11 | 0.116 - 0.995
# epoch:12 | 0.116 - 0.997
# epoch:13 | 0.116 - 0.999
# epoch:14 | 0.116 - 0.999
# epoch:15 | 0.116 - 0.999
# epoch:16 | 0.116 - 1.0
# epoch:17 | 0.116 - 1.0
# epoch:18 | 0.116 - 1.0
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 1.0
# ============== 10/16 ==============
# epoch:0 | 0.117 - 0.155
# epoch:1 | 0.117 - 0.664
# epoch:2 | 0.117 - 0.74
# epoch:3 | 0.117 - 0.807
# epoch:4 | 0.117 - 0.858
# epoch:5 | 0.117 - 0.957
# epoch:6 | 0.117 - 0.963
# epoch:7 | 0.117 - 0.981
# epoch:8 | 0.117 - 0.967
# epoch:9 | 0.117 - 0.99
# epoch:10 | 0.117 - 0.993
# epoch:11 | 0.117 - 0.992
# epoch:12 | 0.117 - 0.997
# epoch:13 | 0.117 - 0.999
# epoch:14 | 0.117 - 0.999
# epoch:15 | 0.117 - 0.999
# epoch:16 | 0.117 - 0.999
# epoch:17 | 0.117 - 0.999
# epoch:18 | 0.117 - 0.999
# epoch:19 | 0.117 - 0.999
# No handles with labels found to put in legend.
# ============== 11/16 ==============
# epoch:0 | 0.087 - 0.157
# epoch:1 | 0.099 - 0.664
# epoch:2 | 0.099 - 0.734
# epoch:3 | 0.116 - 0.81
# epoch:4 | 0.116 - 0.857
# epoch:5 | 0.116 - 0.915
# epoch:6 | 0.116 - 0.836
# epoch:7 | 0.116 - 0.951
# epoch:8 | 0.116 - 0.95
# epoch:9 | 0.116 - 0.985
# epoch:10 | 0.116 - 0.987
# epoch:11 | 0.116 - 0.993
# epoch:12 | 0.116 - 0.993
# epoch:13 | 0.116 - 0.981
# epoch:14 | 0.116 - 0.995
# epoch:15 | 0.116 - 0.996
# epoch:16 | 0.116 - 0.997
# epoch:17 | 0.116 - 0.997
# epoch:18 | 0.117 - 0.997
# epoch:19 | 0.117 - 0.913
# No handles with labels found to put in legend.
# ============== 12/16 ==============
# epoch:0 | 0.116 - 0.107
# epoch:1 | 0.116 - 0.509
# epoch:2 | 0.116 - 0.739
# epoch:3 | 0.117 - 0.793
# epoch:4 | 0.117 - 0.797
# epoch:5 | 0.117 - 0.838
# epoch:6 | 0.117 - 0.859
# epoch:7 | 0.117 - 0.866
# epoch:8 | 0.117 - 0.885
# epoch:9 | 0.117 - 0.842
# epoch:10 | 0.117 - 0.893
# epoch:11 | 0.117 - 0.89
# epoch:12 | 0.117 - 0.894
# epoch:13 | 0.117 - 0.912
# epoch:14 | 0.117 - 0.907
# epoch:15 | 0.117 - 0.907
# epoch:16 | 0.117 - 0.904
# epoch:17 | 0.117 - 0.904
# epoch:18 | 0.117 - 0.909
# epoch:19 | 0.117 - 0.907
# No handles with labels found to put in legend.
# ============== 13/16 ==============
# epoch:0 | 0.117 - 0.09
# epoch:1 | 0.116 - 0.476
# epoch:2 | 0.116 - 0.522
# epoch:3 | 0.117 - 0.538
# epoch:4 | 0.117 - 0.613
# epoch:5 | 0.117 - 0.608
# epoch:6 | 0.116 - 0.653
# epoch:7 | 0.117 - 0.678
# epoch:8 | 0.116 - 0.671
# epoch:9 | 0.116 - 0.683
# epoch:10 | 0.116 - 0.688
# epoch:11 | 0.116 - 0.697
# epoch:12 | 0.116 - 0.688
# epoch:13 | 0.116 - 0.691
# epoch:14 | 0.116 - 0.768
# epoch:15 | 0.116 - 0.8
# epoch:16 | 0.116 - 0.802
# epoch:17 | 0.116 - 0.803
# epoch:18 | 0.116 - 0.787
# epoch:19 | 0.116 - 0.801
# No handles with labels found to put in legend.
# ============== 14/16 ==============
# epoch:0 | 0.117 - 0.116
# epoch:1 | 0.117 - 0.444
# epoch:2 | 0.117 - 0.434
# epoch:3 | 0.117 - 0.578
# epoch:4 | 0.116 - 0.52
# epoch:5 | 0.116 - 0.577
# epoch:6 | 0.116 - 0.589
# epoch:7 | 0.116 - 0.521
# epoch:8 | 0.116 - 0.543
# epoch:9 | 0.116 - 0.587
# epoch:10 | 0.116 - 0.559
# epoch:11 | 0.116 - 0.583
# epoch:12 | 0.116 - 0.682
# epoch:13 | 0.116 - 0.698
# epoch:14 | 0.116 - 0.684
# epoch:15 | 0.116 - 0.698
# epoch:16 | 0.116 - 0.681
# epoch:17 | 0.116 - 0.705
# No handles with labels found to put in legend.
# epoch:18 | 0.116 - 0.705
# epoch:19 | 0.116 - 0.707
# ============== 15/16 ==============
# epoch:0 | 0.116 - 0.215
# epoch:1 | 0.117 - 0.308
# epoch:2 | 0.117 - 0.487
# epoch:3 | 0.117 - 0.494
# epoch:4 | 0.117 - 0.587
# epoch:5 | 0.117 - 0.441
# epoch:6 | 0.117 - 0.597
# epoch:7 | 0.117 - 0.588
# epoch:8 | 0.116 - 0.599
# epoch:9 | 0.116 - 0.612
# epoch:10 | 0.116 - 0.592
# epoch:11 | 0.116 - 0.612
# epoch:12 | 0.116 - 0.617
# epoch:13 | 0.116 - 0.534
# epoch:14 | 0.116 - 0.611
# epoch:15 | 0.116 - 0.61
# epoch:16 | 0.116 - 0.62
# epoch:17 | 0.116 - 0.619
# epoch:18 | 0.116 - 0.62
# No handles with labels found to put in legend.
# epoch:19 | 0.116 - 0.625
# ============== 16/16 ==============
# epoch:0 | 0.094 - 0.274
# epoch:1 | 0.117 - 0.291
# epoch:2 | 0.116 - 0.4
# epoch:3 | 0.116 - 0.408
# epoch:4 | 0.116 - 0.479
# epoch:5 | 0.116 - 0.47
# epoch:6 | 0.117 - 0.501
# epoch:7 | 0.116 - 0.497
# epoch:8 | 0.116 - 0.514
# epoch:9 | 0.117 - 0.503
# epoch:10 | 0.117 - 0.516
# epoch:11 | 0.117 - 0.515
# epoch:12 | 0.117 - 0.52
# epoch:13 | 0.117 - 0.485
# epoch:14 | 0.117 - 0.507
# epoch:15 | 0.117 - 0.499
# epoch:16 | 0.117 - 0.52
# epoch:17 | 0.117 - 0.51
# epoch:18 | 0.117 - 0.523
# epoch:19 | 0.117 - 0.524

# %%
# p.190 6.4.1 過学習
import numpy as np
import matplotlib.pyplot as plt
from mnist import load_mnist
from multi_layer_net import MultiLayerNet

(x_trian, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# weight decay (荷重減衰) の設定
# weight_decay_lamda = 0 # weight decay を使用しない場合
weight_decay_lambda = 0.1

network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                       output_size=10,
                       weight_decay_lambda=weight_decay_lambda)
optimizer = SGD(lr=0.01)

max_epochs = 201
train_size = x_train.shape[0]
batch_size = 100

train_loss_list = []
train_acc_list = []
test_acc_list = []

iter_per_epoch = max(train_size / batch_size, 1)
epoch_cnt = 0

for i in range(1000000000):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    t_batch = t_train[batch_mask]
    
    grads = network.gradient(x_batch, t_batch)
    optimizer.update(network.params, grads)
    
    if i % iter_per_epoch == 0:
        train_acc = network.accuracy(x_train, t_train)
        test_acc = network.accuracy(x_test, t_test)
        train_acc_list.append(train_acc)
        test_acc_list.append(test_acc)
        
        print("epoch:" + str(epoch_cnt) + ", train acc:" + str(train_acc) + ", test acc:" + str(test_acc))
        
        epoch_cnt += 1
        if epoch_cnt >= max_epochs:
            break
            
# グラフの描画
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.legend(loc='lower right')
plt.show()
# Out:
# epoch:0, train acc:0.21, test acc:0.1873
# epoch:1, train acc:0.25, test acc:0.2067
# epoch:2, train acc:0.2633333333333333, test acc:0.2209
# epoch:3, train acc:0.2966666666666667, test acc:0.2488
# epoch:4, train acc:0.3333333333333333, test acc:0.2747
# epoch:5, train acc:0.35, test acc:0.2877
# epoch:6, train acc:0.3566666666666667, test acc:0.3054
# epoch:7, train acc:0.37666666666666665, test acc:0.3109
# epoch:8, train acc:0.38666666666666666, test acc:0.3175
# epoch:9, train acc:0.38333333333333336, test acc:0.3191
# epoch:10, train acc:0.3933333333333333, test acc:0.324
# epoch:11, train acc:0.39666666666666667, test acc:0.3265
# epoch:12, train acc:0.42, test acc:0.3417
# epoch:13, train acc:0.4266666666666667, test acc:0.3441
# epoch:14, train acc:0.43666666666666665, test acc:0.3493
# epoch:15, train acc:0.43, test acc:0.3497
# epoch:16, train acc:0.4533333333333333, test acc:0.3594
# epoch:17, train acc:0.45, test acc:0.3601
# epoch:18, train acc:0.4266666666666667, test acc:0.3487
# epoch:19, train acc:0.44, test acc:0.3474
# epoch:20, train acc:0.45666666666666667, test acc:0.347
# epoch:21, train acc:0.45666666666666667, test acc:0.3592
# epoch:22, train acc:0.4766666666666667, test acc:0.3644
# epoch:23, train acc:0.46, test acc:0.3516
# epoch:24, train acc:0.4766666666666667, test acc:0.3678
# epoch:25, train acc:0.49666666666666665, test acc:0.3807
# epoch:26, train acc:0.5, test acc:0.3858
# epoch:27, train acc:0.5166666666666667, test acc:0.4096
# epoch:28, train acc:0.53, test acc:0.4132
# epoch:29, train acc:0.52, test acc:0.4073
# epoch:30, train acc:0.53, test acc:0.4124
# epoch:31, train acc:0.5633333333333334, test acc:0.4261
# epoch:32, train acc:0.58, test acc:0.4384
# epoch:33, train acc:0.5933333333333334, test acc:0.4589
# epoch:34, train acc:0.5933333333333334, test acc:0.4686
# epoch:35, train acc:0.61, test acc:0.4843
# epoch:36, train acc:0.6133333333333333, test acc:0.4916
# epoch:37, train acc:0.6166666666666667, test acc:0.5039
# epoch:38, train acc:0.6333333333333333, test acc:0.5117
# epoch:39, train acc:0.6266666666666667, test acc:0.5121
# epoch:40, train acc:0.66, test acc:0.5306
# epoch:41, train acc:0.68, test acc:0.5429
# epoch:42, train acc:0.67, test acc:0.5449
# epoch:43, train acc:0.6933333333333334, test acc:0.5601
# epoch:44, train acc:0.6966666666666667, test acc:0.5733
# epoch:45, train acc:0.6833333333333333, test acc:0.5635
# epoch:46, train acc:0.7033333333333334, test acc:0.5741
# epoch:47, train acc:0.7066666666666667, test acc:0.5799
# epoch:48, train acc:0.7233333333333334, test acc:0.5869
# epoch:49, train acc:0.73, test acc:0.5898
# epoch:50, train acc:0.7633333333333333, test acc:0.602
# epoch:51, train acc:0.73, test acc:0.5942
# epoch:52, train acc:0.7433333333333333, test acc:0.5901
# epoch:53, train acc:0.75, test acc:0.6065
# epoch:54, train acc:0.76, test acc:0.6144
# epoch:55, train acc:0.76, test acc:0.6164
# epoch:56, train acc:0.7733333333333333, test acc:0.6181
# epoch:57, train acc:0.7833333333333333, test acc:0.6278
# epoch:58, train acc:0.81, test acc:0.6389
# epoch:59, train acc:0.8, test acc:0.6416
# epoch:60, train acc:0.8133333333333334, test acc:0.6373
# epoch:61, train acc:0.8033333333333333, test acc:0.6206
# epoch:62, train acc:0.82, test acc:0.6426
# epoch:63, train acc:0.8233333333333334, test acc:0.65
# epoch:64, train acc:0.81, test acc:0.648
# epoch:65, train acc:0.8133333333333334, test acc:0.6548
# epoch:66, train acc:0.82, test acc:0.6544
# epoch:67, train acc:0.8433333333333334, test acc:0.6659
# epoch:68, train acc:0.8233333333333334, test acc:0.6505
# epoch:69, train acc:0.82, test acc:0.6519
# epoch:70, train acc:0.81, test acc:0.6519
# epoch:71, train acc:0.84, test acc:0.6554
# epoch:72, train acc:0.8533333333333334, test acc:0.6705
# epoch:73, train acc:0.8533333333333334, test acc:0.6827
# epoch:74, train acc:0.8433333333333334, test acc:0.6709
# epoch:75, train acc:0.8366666666666667, test acc:0.6731
# epoch:76, train acc:0.8366666666666667, test acc:0.67
# epoch:77, train acc:0.8466666666666667, test acc:0.6793
# epoch:78, train acc:0.85, test acc:0.6676
# epoch:79, train acc:0.8533333333333334, test acc:0.6775
# epoch:80, train acc:0.86, test acc:0.674
# epoch:81, train acc:0.86, test acc:0.688
# epoch:82, train acc:0.85, test acc:0.6762
# epoch:83, train acc:0.86, test acc:0.6869
# epoch:84, train acc:0.8633333333333333, test acc:0.6878
# epoch:85, train acc:0.8566666666666667, test acc:0.6749
# epoch:86, train acc:0.8633333333333333, test acc:0.6922
# epoch:87, train acc:0.85, test acc:0.677
# epoch:88, train acc:0.85, test acc:0.6822
# epoch:89, train acc:0.86, test acc:0.678
# epoch:90, train acc:0.8633333333333333, test acc:0.6915
# epoch:91, train acc:0.8666666666666667, test acc:0.6987
# epoch:92, train acc:0.8633333333333333, test acc:0.6961
# epoch:93, train acc:0.87, test acc:0.7
# epoch:94, train acc:0.8733333333333333, test acc:0.6991
# epoch:95, train acc:0.8766666666666667, test acc:0.6952
# epoch:96, train acc:0.8733333333333333, test acc:0.694
# epoch:97, train acc:0.87, test acc:0.7062
# epoch:98, train acc:0.8866666666666667, test acc:0.7091
# epoch:99, train acc:0.8866666666666667, test acc:0.7084
# epoch:100, train acc:0.8766666666666667, test acc:0.6999
# epoch:101, train acc:0.89, test acc:0.7138
# epoch:102, train acc:0.8766666666666667, test acc:0.7087
# epoch:103, train acc:0.8833333333333333, test acc:0.7049
# epoch:104, train acc:0.88, test acc:0.7076
# epoch:105, train acc:0.8833333333333333, test acc:0.7168
# epoch:106, train acc:0.8866666666666667, test acc:0.703
# epoch:107, train acc:0.8733333333333333, test acc:0.693
# epoch:108, train acc:0.88, test acc:0.6984
# epoch:109, train acc:0.89, test acc:0.7099
# epoch:110, train acc:0.8966666666666666, test acc:0.7189
# epoch:111, train acc:0.8933333333333333, test acc:0.7147
# epoch:112, train acc:0.9, test acc:0.7258
# epoch:113, train acc:0.89, test acc:0.7134
# epoch:114, train acc:0.8966666666666666, test acc:0.7196
# epoch:115, train acc:0.9, test acc:0.723
# epoch:116, train acc:0.8966666666666666, test acc:0.7207
# epoch:117, train acc:0.8966666666666666, test acc:0.7162
# epoch:118, train acc:0.9, test acc:0.7107
# epoch:119, train acc:0.8766666666666667, test acc:0.6995
# epoch:120, train acc:0.9, test acc:0.7147
# epoch:121, train acc:0.9, test acc:0.7131
# epoch:122, train acc:0.89, test acc:0.7147
# epoch:123, train acc:0.89, test acc:0.707
# epoch:124, train acc:0.9, test acc:0.7121
# epoch:125, train acc:0.91, test acc:0.7193
# epoch:126, train acc:0.9, test acc:0.7157
# epoch:127, train acc:0.9066666666666666, test acc:0.7182
# epoch:128, train acc:0.8966666666666666, test acc:0.7144
# epoch:129, train acc:0.9033333333333333, test acc:0.7216
# epoch:130, train acc:0.89, test acc:0.7101
# epoch:131, train acc:0.9066666666666666, test acc:0.7246
# epoch:132, train acc:0.9, test acc:0.7283
# epoch:133, train acc:0.9033333333333333, test acc:0.7152
# epoch:134, train acc:0.89, test acc:0.7128
# epoch:135, train acc:0.9033333333333333, test acc:0.7158
# epoch:136, train acc:0.89, test acc:0.7181
# epoch:137, train acc:0.91, test acc:0.7266
# epoch:138, train acc:0.9066666666666666, test acc:0.7323
# epoch:139, train acc:0.9033333333333333, test acc:0.7278
# epoch:140, train acc:0.9033333333333333, test acc:0.7243
# epoch:141, train acc:0.9066666666666666, test acc:0.7217
# epoch:142, train acc:0.9033333333333333, test acc:0.72
# epoch:143, train acc:0.9, test acc:0.7242
# epoch:144, train acc:0.9033333333333333, test acc:0.7232
# epoch:145, train acc:0.91, test acc:0.7249
# epoch:146, train acc:0.9033333333333333, test acc:0.7158
# epoch:147, train acc:0.9, test acc:0.7231
# epoch:148, train acc:0.9033333333333333, test acc:0.7257
# epoch:149, train acc:0.9233333333333333, test acc:0.7351
# epoch:150, train acc:0.9033333333333333, test acc:0.7324
# epoch:151, train acc:0.9066666666666666, test acc:0.7303
# epoch:152, train acc:0.91, test acc:0.7312
# epoch:153, train acc:0.9133333333333333, test acc:0.7293
# epoch:154, train acc:0.9133333333333333, test acc:0.7321
# epoch:155, train acc:0.91, test acc:0.7331
# epoch:156, train acc:0.91, test acc:0.73
# epoch:157, train acc:0.92, test acc:0.7345
# epoch:158, train acc:0.91, test acc:0.7331
# epoch:159, train acc:0.9166666666666666, test acc:0.736
# epoch:160, train acc:0.92, test acc:0.7357
# epoch:161, train acc:0.9033333333333333, test acc:0.7261
# epoch:162, train acc:0.9166666666666666, test acc:0.7373
# epoch:163, train acc:0.9166666666666666, test acc:0.7397
# epoch:164, train acc:0.9233333333333333, test acc:0.74
# epoch:165, train acc:0.9133333333333333, test acc:0.7333
# epoch:166, train acc:0.9133333333333333, test acc:0.7318
# epoch:167, train acc:0.9133333333333333, test acc:0.7318
# epoch:168, train acc:0.91, test acc:0.732
# epoch:169, train acc:0.9166666666666666, test acc:0.7404
# epoch:170, train acc:0.92, test acc:0.7378
# epoch:171, train acc:0.9133333333333333, test acc:0.722
# epoch:172, train acc:0.9033333333333333, test acc:0.7288
# epoch:173, train acc:0.9033333333333333, test acc:0.723
# epoch:174, train acc:0.91, test acc:0.7271
# epoch:175, train acc:0.9, test acc:0.7303
# epoch:176, train acc:0.9233333333333333, test acc:0.7357
# epoch:177, train acc:0.9133333333333333, test acc:0.7342
# epoch:178, train acc:0.92, test acc:0.7303
# epoch:179, train acc:0.9133333333333333, test acc:0.7335
# epoch:180, train acc:0.9133333333333333, test acc:0.7277
# epoch:181, train acc:0.91, test acc:0.7293
# epoch:182, train acc:0.9033333333333333, test acc:0.7259
# epoch:183, train acc:0.9166666666666666, test acc:0.7285
# epoch:184, train acc:0.9033333333333333, test acc:0.7183
# epoch:185, train acc:0.9, test acc:0.7234
# epoch:186, train acc:0.92, test acc:0.7307
# epoch:187, train acc:0.92, test acc:0.7326
# epoch:188, train acc:0.9133333333333333, test acc:0.7312
# epoch:189, train acc:0.92, test acc:0.7392
# epoch:190, train acc:0.9066666666666666, test acc:0.7259
# epoch:191, train acc:0.92, test acc:0.7366
# epoch:192, train acc:0.9066666666666666, test acc:0.734
# epoch:193, train acc:0.91, test acc:0.7342
# epoch:194, train acc:0.9133333333333333, test acc:0.7334
# epoch:195, train acc:0.9066666666666666, test acc:0.7278
# epoch:196, train acc:0.9133333333333333, test acc:0.7335
# epoch:197, train acc:0.9166666666666666, test acc:0.7374
# epoch:198, train acc:0.9133333333333333, test acc:0.7375
# epoch:199, train acc:0.9133333333333333, test acc:0.7323
# epoch:200, train acc:0.92, test acc:0.731

# %%
import numpy as np
import matplotlib.pyplot as plt
from mnist import load_mnist
from multi_layer_net_extend import MultiLayerNetExtend
from trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 過学習を再現するために、学習データを削減
x_train = x_train[:300]
t_train = t_train[:300]

# Dropoutの有無、割合の設定
use_dropout = True
dropout_ratio = 0.2

network = MultiLayerNetExtend(input_size=784, hidden_size_list = [100, 100, 100, 100, 100, 100],
                             output_size=10, use_dropout=use_dropout, dropout_ration=dropout_ratio)
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                 epochs=301, mini_batch_size=100,
                 optimizer='sgd', optimizer_param={'lr':0.01},
                 verbose=True)
trainer.train()

train_acc_list, test_acc_list = trainer.train_acc_list, trainer.test_acc_list

# グラフの描画
markers = {'train': 'o', 'test': 's'}
x = np.arange(len(train_acc_list))
plt.plot(x, train_acc_list, marker='o', label='train', markevery=10)
plt.plot(x, test_acc_list, marker='s', label='test', markevery=10)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc = 'lower right')
plt.show()
# Out:
# train loss:2.3161752618141893
# === epoch:1, train acc:0.08333333333333333, test acc:0.0902 ===
# train loss:2.310868257380288
# train loss:2.3053605477812478
# train loss:2.2984171291916384
# === epoch:2, train acc:0.08333333333333333, test acc:0.0949 ===
# train loss:2.307574369398944
# train loss:2.3161959685020492
# train loss:2.3255161373623014
# === epoch:3, train acc:0.08666666666666667, test acc:0.0978 ===
# train loss:2.3130720004078897
# train loss:2.296956239632734
# train loss:2.30637146200787
# === epoch:4, train acc:0.10333333333333333, test acc:0.102 ===
# train loss:2.303566051604019
# train loss:2.3109870702397592
# train loss:2.314213986722531
# === epoch:5, train acc:0.11, test acc:0.1039 ===
# train loss:2.3034240104825234
# train loss:2.2999511443465233
# train loss:2.299710009969184
# === epoch:6, train acc:0.12333333333333334, test acc:0.1067 ===
# train loss:2.299345011107101
# train loss:2.306694442434978
# train loss:2.2943497593254025
# === epoch:7, train acc:0.12333333333333334, test acc:0.1092 ===
# train loss:2.3001842300944104
# train loss:2.291742475803984
# train loss:2.296374032776237
# === epoch:8, train acc:0.13333333333333333, test acc:0.1112 ===
# train loss:2.2900183575991293
# train loss:2.2939145925618547
# train loss:2.3007933732136117
# === epoch:9, train acc:0.13, test acc:0.1151 ===
# train loss:2.3027751386197606
# train loss:2.2845499911912173
# train loss:2.294419073180269
# === epoch:10, train acc:0.14, test acc:0.1164 ===
# train loss:2.2867997849106656
# train loss:2.297581883769123
# train loss:2.2781538335775755
# === epoch:11, train acc:0.14333333333333334, test acc:0.1229 ===
# train loss:2.288393313524345
# train loss:2.294731555893951
# train loss:2.2814803902350906
# === epoch:12, train acc:0.16, test acc:0.1275 ===
# train loss:2.292911305059224
# train loss:2.2901813371513016
# train loss:2.289252948089501
# === epoch:13, train acc:0.17, test acc:0.1331 ===
# train loss:2.2792343868638496
# train loss:2.2811171778486354
# train loss:2.2947875942684566
# === epoch:14, train acc:0.17, test acc:0.1372 ===
# train loss:2.2950275753010496
# train loss:2.2837443558099526
# train loss:2.27614320723727
# === epoch:15, train acc:0.17666666666666667, test acc:0.1428 ===
# train loss:2.2878255719146567
# train loss:2.2792435529515025
# train loss:2.3037367239590862
# === epoch:16, train acc:0.17, test acc:0.145 ===
# train loss:2.2751461650231404
# train loss:2.288805855177506
# train loss:2.2868964016533324
# === epoch:17, train acc:0.18333333333333332, test acc:0.1498 ===
# train loss:2.2650592852283684
# train loss:2.281040414478844
# train loss:2.2873861198189216
# === epoch:18, train acc:0.2, test acc:0.1554 ===
# train loss:2.270916758419651
# train loss:2.275453933449883
# train loss:2.2827489783205874
# === epoch:19, train acc:0.21, test acc:0.1596 ===
# train loss:2.29172838866432
# train loss:2.2806834821464124
# train loss:2.2731571063777705
# === epoch:20, train acc:0.21, test acc:0.1611 ===
# train loss:2.2742242048449155
# train loss:2.2725713964695675
# train loss:2.2713339322697355
# === epoch:21, train acc:0.22333333333333333, test acc:0.1658 ===
# train loss:2.2846170740167353
# train loss:2.263386232428338
# train loss:2.274663578939889
# === epoch:22, train acc:0.23, test acc:0.1702 ===
# train loss:2.271810167106517
# train loss:2.274069382520209
# train loss:2.272497475972577
# === epoch:23, train acc:0.23333333333333334, test acc:0.1748 ===
# train loss:2.2812042269064974
# train loss:2.2775414299066417
# train loss:2.2804124763507883
# === epoch:24, train acc:0.25333333333333335, test acc:0.1785 ===
# train loss:2.2783557157658896
# train loss:2.26268354747266
# train loss:2.2766885214991395
# === epoch:25, train acc:0.25666666666666665, test acc:0.1865 ===
# train loss:2.276144375133012
# train loss:2.265076292617761
# train loss:2.2595992048252467
# === epoch:26, train acc:0.25666666666666665, test acc:0.1913 ===
# train loss:2.270855695809879
# train loss:2.2578505243494478
# train loss:2.276174018206801
# === epoch:27, train acc:0.26, test acc:0.1931 ===
# train loss:2.2624973850583494
# train loss:2.2563092311024757
# train loss:2.2590392265823227
# === epoch:28, train acc:0.26, test acc:0.1963 ===
# train loss:2.2793130932214876
# train loss:2.2727657215732777
# train loss:2.27084548171893
# === epoch:29, train acc:0.27, test acc:0.2018 ===
# train loss:2.2674115048177605
# train loss:2.2767117256285028
# train loss:2.2668388183346426
# === epoch:30, train acc:0.28, test acc:0.2022 ===
# train loss:2.256530784289413
# train loss:2.244810802477642
# train loss:2.255933107543773
# === epoch:31, train acc:0.27666666666666667, test acc:0.2048 ===
# train loss:2.2504552040525185
# train loss:2.2526463197754865
# train loss:2.2677093309836613
# === epoch:32, train acc:0.27666666666666667, test acc:0.2083 ===
# train loss:2.2517273338398693
# train loss:2.2685638720908297
# train loss:2.2633667568829514
# === epoch:33, train acc:0.2733333333333333, test acc:0.211 ===
# train loss:2.2574405424486237
# train loss:2.258906129117016
# train loss:2.2606197868894036
# === epoch:34, train acc:0.2866666666666667, test acc:0.2159 ===
# train loss:2.2490172377609254
# train loss:2.2530102345777183
# train loss:2.2724242190451442
# === epoch:35, train acc:0.27666666666666667, test acc:0.217 ===
# train loss:2.264224715421487
# train loss:2.236773951556602
# train loss:2.2623014610286076
# === epoch:36, train acc:0.2966666666666667, test acc:0.2198 ===
# train loss:2.2638097661678622
# train loss:2.270580916982797
# train loss:2.2469171719967793
# === epoch:37, train acc:0.2966666666666667, test acc:0.2235 ===
# train loss:2.227015259900167
# train loss:2.2534939219055907
# train loss:2.245684109488143
# === epoch:38, train acc:0.2966666666666667, test acc:0.2292 ===
# train loss:2.242699622498925
# train loss:2.251877932901242
# train loss:2.242055905782075
# === epoch:39, train acc:0.2966666666666667, test acc:0.2313 ===
# train loss:2.2485123326393848
# train loss:2.2321814312771444
# train loss:2.240543780276685
# === epoch:40, train acc:0.30333333333333334, test acc:0.2351 ===
# train loss:2.2541980679456888
# train loss:2.2486081059779246
# train loss:2.2374714602119425
# === epoch:41, train acc:0.30333333333333334, test acc:0.236 ===
# train loss:2.250664293746794
# train loss:2.2475909953179434
# train loss:2.2484703734641336
# === epoch:42, train acc:0.30333333333333334, test acc:0.2412 ===
# train loss:2.2375387076771016
# train loss:2.2469709690793267
# train loss:2.246843684279833
# === epoch:43, train acc:0.32, test acc:0.2436 ===
# train loss:2.2174978341366143
# train loss:2.2388131067681827
# train loss:2.2428977403756987
# === epoch:44, train acc:0.32666666666666666, test acc:0.2476 ===
# train loss:2.2293388497844675
# train loss:2.2396852700580756
# train loss:2.2521315955987267
# === epoch:45, train acc:0.3333333333333333, test acc:0.2549 ===
# train loss:2.2447268770797963
# train loss:2.2320387157753547
# train loss:2.238675179205251
# === epoch:46, train acc:0.33666666666666667, test acc:0.26 ===
# train loss:2.2100760179813657
# train loss:2.2345555952638474
# train loss:2.246912199502286
# === epoch:47, train acc:0.32666666666666666, test acc:0.2599 ===
# train loss:2.2359305593677505
# train loss:2.2304086733665125
# train loss:2.2258233662608315
# === epoch:48, train acc:0.32666666666666666, test acc:0.2631 ===
# train loss:2.232187785168298
# train loss:2.216781025966641
# train loss:2.243923505621373
# === epoch:49, train acc:0.34, test acc:0.2676 ===
# train loss:2.2387682593834226
# train loss:2.2408237789003933
# train loss:2.203922304364504
# === epoch:50, train acc:0.33666666666666667, test acc:0.2723 ===
# train loss:2.214845766111745
# train loss:2.212810002562613
# train loss:2.23415587925106
# === epoch:51, train acc:0.3433333333333333, test acc:0.2759 ===
# train loss:2.208909140758823
# train loss:2.246708381188761
# train loss:2.1990397771132337
# === epoch:52, train acc:0.35, test acc:0.278 ===
# train loss:2.2082525679235236
# train loss:2.22235714401318
# train loss:2.2286078745673383
# === epoch:53, train acc:0.3466666666666667, test acc:0.2767 ===
# train loss:2.2167274881216117
# train loss:2.218160393932752
# train loss:2.2269915943804826
# === epoch:54, train acc:0.35, test acc:0.2803 ===
# train loss:2.1842365664219545
# train loss:2.2569224842035256
# train loss:2.215259058957804
# === epoch:55, train acc:0.3466666666666667, test acc:0.2793 ===
# train loss:2.261843713575037
# train loss:2.2367847627860447
# train loss:2.223317570549836
# === epoch:56, train acc:0.3566666666666667, test acc:0.2826 ===
# train loss:2.212535528399707
# train loss:2.1891802046185784
# train loss:2.2308905858068635
# === epoch:57, train acc:0.3433333333333333, test acc:0.2816 ===
# train loss:2.1974449774867297
# train loss:2.230482106116234
# train loss:2.227907674108579
# === epoch:58, train acc:0.3466666666666667, test acc:0.2832 ===
# train loss:2.20999339012697
# train loss:2.2264754804387543
# train loss:2.2413251684348188
# === epoch:59, train acc:0.35333333333333333, test acc:0.2877 ===
# train loss:2.23097427182309
# train loss:2.197580386640879
# train loss:2.2251202433014496
# === epoch:60, train acc:0.3566666666666667, test acc:0.2886 ===
# train loss:2.2169740913243032
# train loss:2.2427479529604946
# train loss:2.225268931976739
# === epoch:61, train acc:0.36333333333333334, test acc:0.2921 ===
# train loss:2.2117007637148887
# train loss:2.2058825409229446
# train loss:2.2203047116569645
# === epoch:62, train acc:0.36666666666666664, test acc:0.2957 ===
# train loss:2.207424867938745
# train loss:2.197728792643064
# train loss:2.1809926384389335
# === epoch:63, train acc:0.37, test acc:0.2962 ===
# train loss:2.2188786814730115
# train loss:2.1988276487455574
# train loss:2.182952003782036
# === epoch:64, train acc:0.37, test acc:0.2987 ===
# train loss:2.1963675588466014
# train loss:2.215878550480411
# train loss:2.2395400367382035
# === epoch:65, train acc:0.37333333333333335, test acc:0.3042 ===
# train loss:2.1903503914292815
# train loss:2.1631431676584483
# train loss:2.213145300891828
# === epoch:66, train acc:0.37333333333333335, test acc:0.3063 ===
# train loss:2.21225614055348
# train loss:2.169361892366665
# train loss:2.1845327856261063
# === epoch:67, train acc:0.37333333333333335, test acc:0.3073 ===
# train loss:2.181462374907469
# train loss:2.1744327239596983
# train loss:2.2011208434242744
# === epoch:68, train acc:0.37333333333333335, test acc:0.3092 ===
# train loss:2.194686730341155
# train loss:2.169574675651985
# train loss:2.176735854407334
# === epoch:69, train acc:0.37, test acc:0.3023 ===
# train loss:2.1601664273497763
# train loss:2.20452282730696
# train loss:2.1991730987973868
# === epoch:70, train acc:0.36666666666666664, test acc:0.2988 ===
# train loss:2.202390223357863
# train loss:2.185330961360434
# train loss:2.175916363234409
# === epoch:71, train acc:0.37333333333333335, test acc:0.3024 ===
# train loss:2.1813623005546963
# train loss:2.201226336057262
# train loss:2.1957751844313336
# === epoch:72, train acc:0.37666666666666665, test acc:0.3046 ===
# train loss:2.189293954318975
# train loss:2.2164790871933073
# train loss:2.154940821204589
# === epoch:73, train acc:0.37666666666666665, test acc:0.3041 ===
# train loss:2.16316673797227
# train loss:2.1723466305840455
# train loss:2.1394378784555004
# === epoch:74, train acc:0.38, test acc:0.3046 ===
# train loss:2.1821727757295553
# train loss:2.168653734795085
# train loss:2.217590418560155
# === epoch:75, train acc:0.37666666666666665, test acc:0.3097 ===
# train loss:2.1517577874264364
# train loss:2.161798262484079
# train loss:2.1721872220229206
# === epoch:76, train acc:0.38333333333333336, test acc:0.3069 ===
# train loss:2.176237574067824
# train loss:2.1327761383012556
# train loss:2.1953950574288044
# === epoch:77, train acc:0.38333333333333336, test acc:0.3088 ===
# train loss:2.1771514486797674
# train loss:2.1517392705545273
# train loss:2.179164636020454
# === epoch:78, train acc:0.38666666666666666, test acc:0.31 ===
# train loss:2.148737250142412
# train loss:2.1360740078416924
# train loss:2.160604070058017
# === epoch:79, train acc:0.38333333333333336, test acc:0.3065 ===
# train loss:2.1546323617804775
# train loss:2.1292197800408843
# train loss:2.1789831671426154
# === epoch:80, train acc:0.38666666666666666, test acc:0.3124 ===
# train loss:2.182945098118489
# train loss:2.1681039189297207
# train loss:2.1690759062668246
# === epoch:81, train acc:0.38666666666666666, test acc:0.3168 ===
# train loss:2.1364105241471325
# train loss:2.1459602343591455
# train loss:2.164889463703275
# === epoch:82, train acc:0.3933333333333333, test acc:0.3176 ===
# train loss:2.173047778841868
# train loss:2.131392336686484
# train loss:2.1253887019625544
# === epoch:83, train acc:0.39, test acc:0.3179 ===
# train loss:2.1384759307331276
# train loss:2.1683006175332675
# train loss:2.1066931400566546
# === epoch:84, train acc:0.38333333333333336, test acc:0.3098 ===
# train loss:2.1645861547607863
# train loss:2.1099985341684877
# train loss:2.1050159880113686
# === epoch:85, train acc:0.37666666666666665, test acc:0.3064 ===
# train loss:2.104278943432581
# train loss:2.1455368131337105
# train loss:2.143236780526507
# === epoch:86, train acc:0.37333333333333335, test acc:0.3057 ===
# train loss:2.163584859299332
# train loss:2.1739307125158813
# train loss:2.098836010462592
# === epoch:87, train acc:0.37666666666666665, test acc:0.309 ===
# train loss:2.159142025843108
# train loss:2.168616604827602
# train loss:2.0956479048383514
# === epoch:88, train acc:0.37333333333333335, test acc:0.3074 ===
# train loss:2.135310844690128
# train loss:2.1089411576980934
# train loss:2.0741366842945954
# === epoch:89, train acc:0.36666666666666664, test acc:0.3049 ===
# train loss:2.043590611246391
# train loss:2.047955690433054
# train loss:2.133860577021941
# === epoch:90, train acc:0.3566666666666667, test acc:0.2992 ===
# train loss:2.0713155377779846
# train loss:2.0984774371764217
# train loss:2.0931302373809664
# === epoch:91, train acc:0.35333333333333333, test acc:0.2962 ===
# train loss:2.1135766530316733
# train loss:2.082949944802412
# train loss:2.0910165266848493
# === epoch:92, train acc:0.3566666666666667, test acc:0.2974 ===
# train loss:2.0820163429427767
# train loss:2.0949960245070303
# train loss:2.089104878604421
# === epoch:93, train acc:0.36333333333333334, test acc:0.3031 ===
# train loss:2.119213512764991
# train loss:2.1065964767889356
# train loss:2.1049640542384283
# === epoch:94, train acc:0.36333333333333334, test acc:0.3043 ===
# train loss:2.1720374631297217
# train loss:2.1157265871452156
# train loss:2.0432425453045546
# === epoch:95, train acc:0.37, test acc:0.3079 ===
# train loss:2.079606540479709
# train loss:2.1337849889492286
# train loss:2.090877090378166
# === epoch:96, train acc:0.36666666666666664, test acc:0.3091 ===
# train loss:2.106447833007836
# train loss:2.141784373128678
# train loss:2.0711713448908693
# === epoch:97, train acc:0.37666666666666665, test acc:0.3113 ===
# train loss:2.132363333933154
# train loss:2.075400913824314
# train loss:2.132437889618329
# === epoch:98, train acc:0.38333333333333336, test acc:0.3164 ===
# train loss:2.08574026996377
# train loss:2.0967001217335732
# train loss:2.075254881966479
# === epoch:99, train acc:0.38666666666666666, test acc:0.3189 ===
# train loss:2.0814545375431353
# train loss:2.027953218488473
# train loss:2.0360280584400656
# === epoch:100, train acc:0.38666666666666666, test acc:0.3186 ===
# train loss:2.0846115729267733
# train loss:2.0739323386383917
# train loss:2.0664046440060337
# === epoch:101, train acc:0.37666666666666665, test acc:0.3182 ===
# train loss:2.0696633544603715
# train loss:2.1085773779405064
# train loss:2.023283641724759
# === epoch:102, train acc:0.38, test acc:0.3228 ===
# train loss:2.1514629736196524
# train loss:2.127898956994107
# train loss:2.0719809388574726
# === epoch:103, train acc:0.39, test acc:0.33 ===
# train loss:2.0835092560863684
# train loss:1.988736573477758
# train loss:2.1439123880822994
# === epoch:104, train acc:0.39, test acc:0.3264 ===
# train loss:2.024744866272998
# train loss:2.0745612870641863
# train loss:2.0587290153618016
# === epoch:105, train acc:0.38666666666666666, test acc:0.3298 ===
# train loss:2.081904711696834
# train loss:2.0521063556162886
# train loss:2.1090080757715475
# === epoch:106, train acc:0.39, test acc:0.3309 ===
# train loss:2.0628279118931347
# train loss:2.093657715116681
# train loss:2.0201236138781926
# === epoch:107, train acc:0.38666666666666666, test acc:0.332 ===
# train loss:2.0324784523788857
# train loss:2.00985201475865
# train loss:2.024138606519474
# === epoch:108, train acc:0.3933333333333333, test acc:0.3326 ===
# train loss:2.06295447089573
# train loss:2.0488012493968086
# train loss:2.043999930822184
# === epoch:109, train acc:0.39, test acc:0.3361 ===
# train loss:2.0536496043044288
# train loss:1.9683154535546228
# train loss:2.0580634181553643
# === epoch:110, train acc:0.4, test acc:0.337 ===
# train loss:2.0948874570284133
# train loss:2.0451228261950547
# train loss:2.0348320343120863
# === epoch:111, train acc:0.4033333333333333, test acc:0.3372 ===
# train loss:2.0696389640248114
# train loss:2.0039845415814375
# train loss:2.020614025176701
# === epoch:112, train acc:0.4, test acc:0.3377 ===
# train loss:1.97860452940257
# train loss:2.0031951334599634
# train loss:2.021471706793891
# === epoch:113, train acc:0.3933333333333333, test acc:0.3316 ===
# train loss:1.9612463506550322
# train loss:1.9809444637437559
# train loss:2.0215325513703375
# === epoch:114, train acc:0.4033333333333333, test acc:0.332 ===
# train loss:2.0325205740118895
# train loss:2.015524751368168
# train loss:2.0247232797016133
# === epoch:115, train acc:0.3933333333333333, test acc:0.336 ===
# train loss:2.026219893798457
# train loss:2.021703005119324
# train loss:1.9218135699753573
# === epoch:116, train acc:0.38333333333333336, test acc:0.336 ===
# train loss:2.057181802707651
# train loss:1.9691675795227093
# train loss:1.9778956704093633
# === epoch:117, train acc:0.38333333333333336, test acc:0.334 ===
# train loss:2.056407280355646
# train loss:2.0300281663540627
# train loss:1.9804713255173658
# === epoch:118, train acc:0.38666666666666666, test acc:0.3341 ===
# train loss:1.896795348647747
# train loss:1.9875542244638185
# train loss:1.9472536917957635
# === epoch:119, train acc:0.38333333333333336, test acc:0.3297 ===
# train loss:2.041782756745191
# train loss:1.951311206419901
# train loss:2.0175793132790103
# === epoch:120, train acc:0.38666666666666666, test acc:0.3307 ===
# train loss:1.9800226185550083
# train loss:2.07070950148573
# train loss:1.9234631586916988
# === epoch:121, train acc:0.38666666666666666, test acc:0.3305 ===
# train loss:1.996347928854335
# train loss:1.956006871218946
# train loss:1.9538590149851052
# === epoch:122, train acc:0.38333333333333336, test acc:0.3298 ===
# train loss:1.9356640394869842
# train loss:1.997204828919716
# train loss:1.924773981432059
# === epoch:123, train acc:0.38333333333333336, test acc:0.3297 ===
# train loss:2.058817661982138
# train loss:2.036391576931148
# train loss:1.9366106686134748
# === epoch:124, train acc:0.3933333333333333, test acc:0.3394 ===
# train loss:1.918634957577188
# train loss:1.9538126377915088
# train loss:2.0053120451083397
# === epoch:125, train acc:0.3933333333333333, test acc:0.3419 ===
# train loss:2.0202052543925966
# train loss:1.9071513549500994
# train loss:2.0867176921748376
# === epoch:126, train acc:0.4033333333333333, test acc:0.3445 ===
# train loss:1.8939733910073477
# train loss:1.9739633256981457
# train loss:1.9249617128410887
# === epoch:127, train acc:0.4033333333333333, test acc:0.3436 ===
# train loss:1.8658532650790227
# train loss:1.9092729623530316
# train loss:1.905846663594486
# === epoch:128, train acc:0.39, test acc:0.3383 ===
# train loss:1.9349262198132273
# train loss:1.9558925947533923
# train loss:1.896685929759149
# === epoch:129, train acc:0.39666666666666667, test acc:0.3375 ===
# train loss:1.996736090522264
# train loss:1.9488442626978522
# train loss:1.9580054298114549
# === epoch:130, train acc:0.39666666666666667, test acc:0.3418 ===
# train loss:1.9376266643281528
# train loss:1.9155477872241045
# train loss:1.9666873087907075
# === epoch:131, train acc:0.4066666666666667, test acc:0.3445 ===
# train loss:1.918629910795218
# train loss:2.0148509561365193
# train loss:1.915148831677988
# === epoch:132, train acc:0.4066666666666667, test acc:0.3466 ===
# train loss:1.8566666650002355
# train loss:1.8076650518027506
# train loss:1.9728876017651285
# === epoch:133, train acc:0.4033333333333333, test acc:0.3455 ===
# train loss:1.8827382106705555
# train loss:1.90555243419535
# train loss:1.8994378350382055
# === epoch:134, train acc:0.41333333333333333, test acc:0.3463 ===
# train loss:1.8979363509878096
# train loss:1.8837500782999015
# train loss:1.9738772337569375
# === epoch:135, train acc:0.41333333333333333, test acc:0.3489 ===
# train loss:1.8474364281175855
# train loss:1.8661268646783737
# train loss:1.8843965902916173
# === epoch:136, train acc:0.41, test acc:0.3463 ===
# train loss:1.961047599524838
# train loss:1.9374881538148296
# train loss:1.9680602044865372
# === epoch:137, train acc:0.42333333333333334, test acc:0.3474 ===
# train loss:1.979210366436233
# train loss:2.0073712029966333
# train loss:1.952027145911103
# === epoch:138, train acc:0.4266666666666667, test acc:0.3479 ===
# train loss:1.8722021543290401
# train loss:1.7814083592090286
# train loss:1.9192350025296492
# === epoch:139, train acc:0.43, test acc:0.3477 ===
# train loss:1.92451568411698
# train loss:1.912966314761232
# train loss:1.8717787139096718
# === epoch:140, train acc:0.43, test acc:0.3476 ===
# train loss:1.8744997362075524
# train loss:1.9062407382881306
# train loss:1.8583357342112734
# === epoch:141, train acc:0.4266666666666667, test acc:0.349 ===
# train loss:1.9807686874595904
# train loss:1.831366990065782
# train loss:2.017359949279062
# === epoch:142, train acc:0.43333333333333335, test acc:0.3515 ===
# train loss:1.7863963899296686
# train loss:1.8016207700592748
# train loss:1.906029942669229
# === epoch:143, train acc:0.43, test acc:0.3494 ===
# train loss:1.8296160766911838
# train loss:1.86529797844884
# train loss:1.8468042991488496
# === epoch:144, train acc:0.43333333333333335, test acc:0.3508 ===
# train loss:1.819088461996415
# train loss:1.9373385317162723
# train loss:1.892859259725979
# === epoch:145, train acc:0.43, test acc:0.3521 ===
# train loss:1.8909732101628949
# train loss:1.7181237828392801
# train loss:1.9269357185644216
# === epoch:146, train acc:0.43666666666666665, test acc:0.3523 ===
# train loss:1.9371795165550632
# train loss:1.86289789807428
# train loss:1.802416405808866
# === epoch:147, train acc:0.44333333333333336, test acc:0.353 ===
# train loss:1.8063241488412678
# train loss:1.8371519161250112
# train loss:1.8908733446592156
# === epoch:148, train acc:0.43666666666666665, test acc:0.3513 ===
# train loss:1.804946493362277
# train loss:1.918328201565976
# train loss:1.9037740778854657
# === epoch:149, train acc:0.45, test acc:0.3546 ===
# train loss:1.790232591165139
# train loss:1.8278534629303829
# train loss:1.8647855813932694
# === epoch:150, train acc:0.45, test acc:0.3543 ===
# train loss:1.7652002638809143
# train loss:1.8641586878577163
# train loss:1.8349854473437415
# === epoch:151, train acc:0.44333333333333336, test acc:0.3541 ===
# train loss:1.8996008558006938
# train loss:1.7818735850315435
# train loss:1.8366379179930632
# === epoch:152, train acc:0.46, test acc:0.3583 ===
# train loss:1.7566125442120588
# train loss:1.829344030781146
# train loss:1.8630637485805186
# === epoch:153, train acc:0.45, test acc:0.3618 ===
# train loss:1.7539424887920827
# train loss:1.8896938387509439
# train loss:1.8006788385809307
# === epoch:154, train acc:0.43666666666666665, test acc:0.3595 ===
# train loss:1.9412340603717735
# train loss:1.7709961697643786
# train loss:1.8162188906891947
# === epoch:155, train acc:0.44, test acc:0.3639 ===
# train loss:1.7853788610105452
# train loss:1.7918720111301363
# train loss:1.9028490801286118
# === epoch:156, train acc:0.4533333333333333, test acc:0.3671 ===
# train loss:1.740975482075824
# train loss:1.7390634823700244
# train loss:1.7868289983280152
# === epoch:157, train acc:0.45, test acc:0.3665 ===
# train loss:1.798484311449565
# train loss:1.7843303919197304
# train loss:1.6824025298921237
# === epoch:158, train acc:0.44666666666666666, test acc:0.3643 ===
# train loss:1.821400368429174
# train loss:1.819327783338212
# train loss:1.8165178275294789
# === epoch:159, train acc:0.44666666666666666, test acc:0.3635 ===
# train loss:1.797038421832846
# train loss:1.7726227546863313
# train loss:1.8607089216955344
# === epoch:160, train acc:0.45666666666666667, test acc:0.3671 ===
# train loss:1.8026690218625978
# train loss:1.819101029007304
# train loss:1.7730687212322396
# === epoch:161, train acc:0.46, test acc:0.3704 ===
# train loss:1.831495050264992
# train loss:1.851264454214751
# train loss:1.7686107122559418
# === epoch:162, train acc:0.45666666666666667, test acc:0.3719 ===
# train loss:1.8131230898671087
# train loss:1.8886346948283244
# train loss:1.6952607458984013
# === epoch:163, train acc:0.45666666666666667, test acc:0.3719 ===
# train loss:1.7530812050298799
# train loss:1.6710695028759681
# train loss:1.6789575598800466
# === epoch:164, train acc:0.4666666666666667, test acc:0.3763 ===
# train loss:1.7843568460219104
# train loss:1.6626151549811063
# train loss:1.7461539174266636
# === epoch:165, train acc:0.4666666666666667, test acc:0.3769 ===
# train loss:1.8157982296054584
# train loss:1.72212759268607
# train loss:1.7826149906386763
# === epoch:166, train acc:0.4766666666666667, test acc:0.3812 ===
# train loss:1.7742281336094836
# train loss:1.7321306986760632
# train loss:1.8724487082909818
# === epoch:167, train acc:0.48333333333333334, test acc:0.3858 ===
# train loss:1.6578964815835908
# train loss:1.753795211588269
# train loss:1.6927583020935162
# === epoch:168, train acc:0.48, test acc:0.3844 ===
# train loss:1.748242844163126
# train loss:1.8326664141003266
# train loss:1.8265959134344818
# === epoch:169, train acc:0.4866666666666667, test acc:0.388 ===
# train loss:1.7499543914537943
# train loss:1.725609251067151
# train loss:1.7068494169102204
# === epoch:170, train acc:0.49333333333333335, test acc:0.3896 ===
# train loss:1.8096117336891278
# train loss:1.6439186147896354
# train loss:1.7928815885837353
# === epoch:171, train acc:0.49666666666666665, test acc:0.3952 ===
# train loss:1.7465263822664772
# train loss:1.8060426944968515
# train loss:1.7477209639589322
# === epoch:172, train acc:0.5033333333333333, test acc:0.3983 ===
# train loss:1.7221157156082862
# train loss:1.6492520312721688
# train loss:1.730178325879378
# === epoch:173, train acc:0.5, test acc:0.3972 ===
# train loss:1.7834004825067304
# train loss:1.724676801631826
# train loss:1.751291509288242
# === epoch:174, train acc:0.5066666666666667, test acc:0.3977 ===
# train loss:1.880960543715583
# train loss:1.7580341140540878
# train loss:1.792707038463102
# === epoch:175, train acc:0.5066666666666667, test acc:0.3993 ===
# train loss:1.7170310893300331
# train loss:1.7786816378113415
# train loss:1.562210781354804
# === epoch:176, train acc:0.51, test acc:0.4002 ===
# train loss:1.771719683973582
# train loss:1.7960038780965988
# train loss:1.7168257416215753
# === epoch:177, train acc:0.51, test acc:0.4027 ===
# train loss:1.646845456282441
# train loss:1.7226860948188614
# train loss:1.7519875370768054
# === epoch:178, train acc:0.5166666666666667, test acc:0.404 ===
# train loss:1.6505575996049102
# train loss:1.7427202482728807
# train loss:1.556668838756157
# === epoch:179, train acc:0.5133333333333333, test acc:0.4027 ===
# train loss:1.7844605010793626
# train loss:1.6230350440678538
# train loss:1.852764441432742
# === epoch:180, train acc:0.5166666666666667, test acc:0.4075 ===
# train loss:1.5711440505775547
# train loss:1.7981497339428687
# train loss:1.62336616644606
# === epoch:181, train acc:0.5233333333333333, test acc:0.409 ===
# train loss:1.731777248799636
# train loss:1.698635956775138
# train loss:1.616411186874866
# === epoch:182, train acc:0.5133333333333333, test acc:0.4109 ===
# train loss:1.7150395764429134
# train loss:1.6408425063310659
# train loss:1.72969219458271
# === epoch:183, train acc:0.5233333333333333, test acc:0.4139 ===
# train loss:1.5973603371154337
# train loss:1.7550051129496849
# train loss:1.7248881703234595
# === epoch:184, train acc:0.52, test acc:0.4148 ===
# train loss:1.6819006616967167
# train loss:1.7504615176416445
# train loss:1.741046758654087
# === epoch:185, train acc:0.52, test acc:0.4174 ===
# train loss:1.724240455991979
# train loss:1.7130421339676483
# train loss:1.6762950824516054
# === epoch:186, train acc:0.52, test acc:0.4173 ===
# train loss:1.7034551538349492
# train loss:1.8015869930524295
# train loss:1.6409589192424898
# === epoch:187, train acc:0.5333333333333333, test acc:0.4166 ===
# train loss:1.7036075852092623
# train loss:1.656789004834922
# train loss:1.7209671644557716
# === epoch:188, train acc:0.5266666666666666, test acc:0.4203 ===
# train loss:1.5718140706232868
# train loss:1.7209121418359572
# train loss:1.7290652442071022
# === epoch:189, train acc:0.53, test acc:0.4233 ===
# train loss:1.6107434770046785
# train loss:1.7389078733394994
# train loss:1.662149158175846
# === epoch:190, train acc:0.5366666666666666, test acc:0.4265 ===
# train loss:1.545951506215574
# train loss:1.6117570196739548
# train loss:1.697710113632416
# === epoch:191, train acc:0.53, test acc:0.4262 ===
# train loss:1.6054942368609262
# train loss:1.7109837090711502
# train loss:1.7120560662743372
# === epoch:192, train acc:0.5366666666666666, test acc:0.4277 ===
# train loss:1.7621801428665984
# train loss:1.577615328707184
# train loss:1.7074342610963198
# === epoch:193, train acc:0.5366666666666666, test acc:0.4306 ===
# train loss:1.6029429813636837
# train loss:1.6949580757985845
# train loss:1.6655214271338918
# === epoch:194, train acc:0.5433333333333333, test acc:0.4337 ===
# train loss:1.6464500644049154
# train loss:1.6060925057959843
# train loss:1.6675902763121366
# === epoch:195, train acc:0.54, test acc:0.4313 ===
# train loss:1.6003361852381852
# train loss:1.52050614316345
# train loss:1.6827400926889668
# === epoch:196, train acc:0.54, test acc:0.4312 ===
# train loss:1.6085684793349424
# train loss:1.6790753590529912
# train loss:1.5421901615891924
# === epoch:197, train acc:0.5433333333333333, test acc:0.4332 ===
# train loss:1.6737365471002716
# train loss:1.6081808501597548
# train loss:1.6338339550792227
# === epoch:198, train acc:0.53, test acc:0.436 ===
# train loss:1.7521032805776418
# train loss:1.7084621967346287
# train loss:1.6032437354610374
# === epoch:199, train acc:0.54, test acc:0.4374 ===
# train loss:1.6993425164572367
# train loss:1.65485022966947
# train loss:1.6117807801925077
# === epoch:200, train acc:0.55, test acc:0.4411 ===
# train loss:1.6008446079457244
# train loss:1.5471038861327187
# train loss:1.648095548544567
# === epoch:201, train acc:0.55, test acc:0.4441 ===
# train loss:1.6354420526074243
# train loss:1.6590717631780674
# train loss:1.5864972627548304
# === epoch:202, train acc:0.55, test acc:0.4466 ===
# train loss:1.5640559775210272
# train loss:1.528354776919532
# train loss:1.6589498870131099
# === epoch:203, train acc:0.55, test acc:0.4475 ===
# train loss:1.6418823422113282
# train loss:1.6211394281444507
# train loss:1.5593887659763883
# === epoch:204, train acc:0.5533333333333333, test acc:0.4504 ===
# train loss:1.7459075978596628
# train loss:1.6340780602327254
# train loss:1.6463585883679217
# === epoch:205, train acc:0.5633333333333334, test acc:0.4526 ===
# train loss:1.5750536726092959
# train loss:1.5512248076135566
# train loss:1.6465302056982898
# === epoch:206, train acc:0.5633333333333334, test acc:0.4527 ===
# train loss:1.7175270877533153
# train loss:1.6730459535893691
# train loss:1.6520075284250502
# === epoch:207, train acc:0.5666666666666667, test acc:0.4574 ===
# train loss:1.5499362724223824
# train loss:1.6653142972079533
# train loss:1.7146178001741794
# === epoch:208, train acc:0.5666666666666667, test acc:0.4583 ===
# train loss:1.635398451731632
# train loss:1.5348372159440222
# train loss:1.7114259696903085
# === epoch:209, train acc:0.5666666666666667, test acc:0.4595 ===
# train loss:1.5379745909177809
# train loss:1.528547045507075
# train loss:1.5686625792160576
# === epoch:210, train acc:0.57, test acc:0.4605 ===
# train loss:1.6979662926130594
# train loss:1.5825388590176457
# train loss:1.4917945279337856
# === epoch:211, train acc:0.57, test acc:0.4632 ===
# train loss:1.5320990662069898
# train loss:1.5223022439130585
# train loss:1.565800572941906
# === epoch:212, train acc:0.57, test acc:0.4631 ===
# train loss:1.496791730257107
# train loss:1.5458050399608674
# train loss:1.5208507506906077
# === epoch:213, train acc:0.57, test acc:0.4616 ===
# train loss:1.761625509883576
# train loss:1.3911392076796512
# train loss:1.5238129628162127
# === epoch:214, train acc:0.57, test acc:0.461 ===
# train loss:1.5235195669884292
# train loss:1.5756109697720297
# train loss:1.7126758128490571
# === epoch:215, train acc:0.57, test acc:0.4659 ===
# train loss:1.569162077604902
# train loss:1.5300706179111898
# train loss:1.515622380570338
# === epoch:216, train acc:0.5666666666666667, test acc:0.4679 ===
# train loss:1.565783175447922
# train loss:1.444265896848947
# train loss:1.4400176661626063
# === epoch:217, train acc:0.57, test acc:0.4675 ===
# train loss:1.5932985301687403
# train loss:1.4312113513789355
# train loss:1.5314972298688616
# === epoch:218, train acc:0.5766666666666667, test acc:0.4692 ===
# train loss:1.4788527523330846
# train loss:1.4591056501247441
# train loss:1.6920045233028893
# === epoch:219, train acc:0.57, test acc:0.4699 ===
# train loss:1.4114377901987905
# train loss:1.4212060789664458
# train loss:1.4438398119465177
# === epoch:220, train acc:0.5733333333333334, test acc:0.468 ===
# train loss:1.5361636888877743
# train loss:1.507123303726324
# train loss:1.4737921934345344
# === epoch:221, train acc:0.5733333333333334, test acc:0.4691 ===
# train loss:1.4716019006029857
# train loss:1.5988100070719122
# train loss:1.5064782675345298
# === epoch:222, train acc:0.5766666666666667, test acc:0.4726 ===
# train loss:1.486907410824825
# train loss:1.5137826523568532
# train loss:1.425841730020926
# === epoch:223, train acc:0.5766666666666667, test acc:0.473 ===
# train loss:1.4144824226049701
# train loss:1.6816410806115771
# train loss:1.6203698580879364
# === epoch:224, train acc:0.5766666666666667, test acc:0.4773 ===
# train loss:1.5775489784298369
# train loss:1.4542251673712048
# train loss:1.5111812690559905
# === epoch:225, train acc:0.5833333333333334, test acc:0.4795 ===
# train loss:1.4566640740234675
# train loss:1.5026305944357068
# train loss:1.5230001761255667
# === epoch:226, train acc:0.59, test acc:0.4806 ===
# train loss:1.5327717213274838
# train loss:1.5266310844260824
# train loss:1.445893474388489
# === epoch:227, train acc:0.5866666666666667, test acc:0.482 ===
# train loss:1.5527349203990368
# train loss:1.4291581705195535
# train loss:1.478016923900376
# === epoch:228, train acc:0.5866666666666667, test acc:0.4856 ===
# train loss:1.5125293388159136
# train loss:1.441616215158375
# train loss:1.5879892607947204
# === epoch:229, train acc:0.5933333333333334, test acc:0.488 ===
# train loss:1.4580251658164665
# train loss:1.523067915207202
# train loss:1.4669894139239699
# === epoch:230, train acc:0.6, test acc:0.489 ===
# train loss:1.5775843878136806
# train loss:1.3950989416117292
# train loss:1.41044032714772
# === epoch:231, train acc:0.5966666666666667, test acc:0.4902 ===
# train loss:1.407627007730745
# train loss:1.5763952172938942
# train loss:1.4500396773805204
# === epoch:232, train acc:0.59, test acc:0.4898 ===
# train loss:1.449175108158053
# train loss:1.3522402394194237
# train loss:1.530350908417978
# === epoch:233, train acc:0.5933333333333334, test acc:0.4908 ===
# train loss:1.3122166432090663
# train loss:1.4960366003646977
# train loss:1.2864090257773992
# === epoch:234, train acc:0.5966666666666667, test acc:0.4912 ===
# train loss:1.5846383383096403
# train loss:1.4455606271928958
# train loss:1.3916824371538292
# === epoch:235, train acc:0.5933333333333334, test acc:0.4934 ===
# train loss:1.4341821305437503
# train loss:1.4580107352480498
# train loss:1.5051255180462961
# === epoch:236, train acc:0.6, test acc:0.4964 ===
# train loss:1.4738256978791944
# train loss:1.403975575807753
# train loss:1.5191837914337882
# === epoch:237, train acc:0.6066666666666667, test acc:0.4981 ===
# train loss:1.5299387633418402
# train loss:1.3480596069247637
# train loss:1.4431972256507282
# === epoch:238, train acc:0.61, test acc:0.5016 ===
# train loss:1.351393891058322
# train loss:1.4086799488392368
# train loss:1.393199449248763
# === epoch:239, train acc:0.6166666666666667, test acc:0.5065 ===
# train loss:1.4710481173816061
# train loss:1.5313040360154107
# train loss:1.4307689690287566
# === epoch:240, train acc:0.6266666666666667, test acc:0.5079 ===
# train loss:1.398534762398301
# train loss:1.3568027200489854
# train loss:1.5258898151101534
# === epoch:241, train acc:0.6233333333333333, test acc:0.5082 ===
# train loss:1.370177964971452
# train loss:1.340405110850952
# train loss:1.3362751421765156
# === epoch:242, train acc:0.62, test acc:0.5061 ===
# train loss:1.300469493974864
# train loss:1.3163846641126529
# train loss:1.4053456932216242
# === epoch:243, train acc:0.62, test acc:0.506 ===
# train loss:1.5427258226341316
# train loss:1.4621353405895008
# train loss:1.4032921655725645
# === epoch:244, train acc:0.6333333333333333, test acc:0.5105 ===
# train loss:1.3109070440001969
# train loss:1.5239267520285928
# train loss:1.3299010543606393
# === epoch:245, train acc:0.63, test acc:0.5094 ===
# train loss:1.545089058848331
# train loss:1.4803667002554033
# train loss:1.2804956560629888
# === epoch:246, train acc:0.63, test acc:0.5116 ===
# train loss:1.4109680084169272
# train loss:1.3661691213793334
# train loss:1.3358571090008065
# === epoch:247, train acc:0.63, test acc:0.5126 ===
# train loss:1.3207104087549855
# train loss:1.557147397280077
# train loss:1.2902511269463028
# === epoch:248, train acc:0.6333333333333333, test acc:0.5158 ===
# train loss:1.3215524474181348
# train loss:1.2862511956637313
# train loss:1.3956052109818458
# === epoch:249, train acc:0.6333333333333333, test acc:0.513 ===
# train loss:1.3323582109866055
# train loss:1.4019067354003025
# train loss:1.3167282505627513
# === epoch:250, train acc:0.6333333333333333, test acc:0.5141 ===
# train loss:1.4520894291008686
# train loss:1.3539285474895515
# train loss:1.407610746645994
# === epoch:251, train acc:0.65, test acc:0.5186 ===
# train loss:1.2569820009642663
# train loss:1.3480594381805753
# train loss:1.344127259116734
# === epoch:252, train acc:0.6433333333333333, test acc:0.5207 ===
# train loss:1.3739099911144625
# train loss:1.3762096443432699
# train loss:1.3867276610668091
# === epoch:253, train acc:0.6433333333333333, test acc:0.5217 ===
# train loss:1.2975385125203547
# train loss:1.3012062978423182
# train loss:1.3828084133144674
# === epoch:254, train acc:0.6433333333333333, test acc:0.5232 ===
# train loss:1.3306724057098
# train loss:1.3062761720029161
# train loss:1.2277970708906951
# === epoch:255, train acc:0.6466666666666666, test acc:0.5205 ===
# train loss:1.438110911638527
# train loss:1.3666440602016516
# train loss:1.3590413562911954
# === epoch:256, train acc:0.6366666666666667, test acc:0.5246 ===
# train loss:1.2353293838578636
# train loss:1.4228356542973726
# train loss:1.290040836148634
# === epoch:257, train acc:0.6433333333333333, test acc:0.5228 ===
# train loss:1.4205253709415564
# train loss:1.315911092461366
# train loss:1.3551761032164933
# === epoch:258, train acc:0.6466666666666666, test acc:0.5257 ===
# train loss:1.3598690610991948
# train loss:1.4116121411697813
# train loss:1.3322235264411761
# === epoch:259, train acc:0.65, test acc:0.5282 ===
# train loss:1.3055278095756375
# train loss:1.3570901233658794
# train loss:1.2866041641108914
# === epoch:260, train acc:0.65, test acc:0.5267 ===
# train loss:1.35203056872267
# train loss:1.436419777467576
# train loss:1.492039197033584
# === epoch:261, train acc:0.65, test acc:0.5244 ===
# train loss:1.3187354475511466
# train loss:1.3278744602085022
# train loss:1.329933006116417
# === epoch:262, train acc:0.65, test acc:0.5253 ===
# train loss:1.2526860731667913
# train loss:1.2674982249334057
# train loss:1.2586625323896397
# === epoch:263, train acc:0.65, test acc:0.5235 ===
# train loss:1.4094213208041833
# train loss:1.2858015470599986
# train loss:1.4150867403145924
# === epoch:264, train acc:0.6533333333333333, test acc:0.529 ===
# train loss:1.3743559453550345
# train loss:1.235069700207708
# train loss:1.2919852488717745
# === epoch:265, train acc:0.6433333333333333, test acc:0.5276 ===
# train loss:1.4383970781847057
# train loss:1.2057408784560655
# train loss:1.3887942412583527
# === epoch:266, train acc:0.6466666666666666, test acc:0.5274 ===
# train loss:1.3443174942169411
# train loss:1.159557644587115
# train loss:1.360190681379309
# === epoch:267, train acc:0.6466666666666666, test acc:0.5317 ===
# train loss:1.168983076784333
# train loss:1.3668187210147833
# train loss:1.2266183966399624
# === epoch:268, train acc:0.6433333333333333, test acc:0.5303 ===
# train loss:1.3364520676283291
# train loss:1.4051430839397256
# train loss:1.4091739418901736
# === epoch:269, train acc:0.6433333333333333, test acc:0.5323 ===
# train loss:1.4036957503995904
# train loss:1.3183450398193926
# train loss:1.3220998837157467
# === epoch:270, train acc:0.65, test acc:0.5344 ===
# train loss:1.3300447728780158
# train loss:1.3055756506955536
# train loss:1.3267822050766278
# === epoch:271, train acc:0.6533333333333333, test acc:0.532 ===
# train loss:1.2804907185254726
# train loss:1.3125048926892557
# train loss:1.2927569606875662
# === epoch:272, train acc:0.6533333333333333, test acc:0.5358 ===
# train loss:1.1722769037432847
# train loss:1.3157838390211105
# train loss:1.1109843263250125
# === epoch:273, train acc:0.65, test acc:0.5327 ===
# train loss:1.2487416375084956
# train loss:1.1365328074563976
# train loss:1.185225818404487
# === epoch:274, train acc:0.6533333333333333, test acc:0.5319 ===
# train loss:1.2206240825946326
# train loss:1.1776398358675495
# train loss:1.3556365635072478
# === epoch:275, train acc:0.66, test acc:0.5373 ===
# train loss:1.271801879147004
# train loss:1.2747670170998855
# train loss:1.192169470404787
# === epoch:276, train acc:0.66, test acc:0.5352 ===
# train loss:1.1479786592412358
# train loss:1.2508689187466713
# train loss:1.188412550677968
# === epoch:277, train acc:0.6566666666666666, test acc:0.5355 ===
# train loss:1.1448033327702967
# train loss:1.2802373238765212
# train loss:1.31839474429217
# === epoch:278, train acc:0.66, test acc:0.535 ===
# train loss:1.3079718679079877
# train loss:1.0979420882165953
# train loss:1.1758727044739827
# === epoch:279, train acc:0.6633333333333333, test acc:0.5411 ===
# train loss:1.2192464410431787
# train loss:1.3198697055624198
# train loss:1.1628769643416395
# === epoch:280, train acc:0.6633333333333333, test acc:0.5425 ===
# train loss:1.256319320076479
# train loss:1.338801566670148
# train loss:1.2217329829196408
# === epoch:281, train acc:0.67, test acc:0.5442 ===
# train loss:1.3183961438525693
# train loss:1.0645972852826247
# train loss:1.1935092751718932
# === epoch:282, train acc:0.6633333333333333, test acc:0.5432 ===
# train loss:1.1523632668414205
# train loss:1.1946894567268993
# train loss:1.3155186266684646
# === epoch:283, train acc:0.6633333333333333, test acc:0.5444 ===
# train loss:1.1972789812161861
# train loss:1.0857102327623742
# train loss:1.1059735647775633
# === epoch:284, train acc:0.6633333333333333, test acc:0.5429 ===
# train loss:1.2210273176748974
# train loss:1.2320273538461912
# train loss:1.1595113629738163
# === epoch:285, train acc:0.66, test acc:0.5437 ===
# train loss:1.144539349085285
# train loss:1.0590081800978681
# train loss:1.1028937164195303
# === epoch:286, train acc:0.66, test acc:0.5433 ===
# train loss:1.1936213605528911
# train loss:1.0775491951606817
# train loss:1.3825933624524303
# === epoch:287, train acc:0.66, test acc:0.5462 ===
# train loss:1.1216164641513384
# train loss:1.120143250804648
# train loss:1.2037755338909617
# === epoch:288, train acc:0.6633333333333333, test acc:0.5481 ===
# train loss:1.1477796851760282
# train loss:1.1182192196544811
# train loss:1.1540655333514764
# === epoch:289, train acc:0.6633333333333333, test acc:0.5475 ===
# train loss:1.2220808830300376
# train loss:1.0384749595914722
# train loss:1.2912427098764767
# === epoch:290, train acc:0.6633333333333333, test acc:0.5503 ===
# train loss:1.196202847625649
# train loss:1.1471647588721503
# train loss:1.1632485628470242
# === epoch:291, train acc:0.6633333333333333, test acc:0.5497 ===
# train loss:1.3741947401108365
# train loss:1.1666650457584213
# train loss:1.1797749311563495
# === epoch:292, train acc:0.6733333333333333, test acc:0.5532 ===
# train loss:1.1581913634141896
# train loss:1.2249291193244622
# train loss:1.1783212470078974
# === epoch:293, train acc:0.6733333333333333, test acc:0.5518 ===
# train loss:1.2630549976875662
# train loss:1.2144375312603142
# train loss:1.100026770528028
# === epoch:294, train acc:0.6666666666666666, test acc:0.5507 ===
# train loss:1.2546892422293383
# train loss:1.1109772978194363
# train loss:1.1011060405567625
# === epoch:295, train acc:0.6666666666666666, test acc:0.5492 ===
# train loss:1.1956413351230208
# train loss:1.2384454993940006
# train loss:1.1787507130161767
# === epoch:296, train acc:0.6733333333333333, test acc:0.553 ===
# train loss:1.0846413256606913
# train loss:1.2511284724221239
# train loss:1.129744450058068
# === epoch:297, train acc:0.6666666666666666, test acc:0.5526 ===
# train loss:1.1000624820456364
# train loss:1.1014499329812228
# train loss:1.0895314519584667
# === epoch:298, train acc:0.6733333333333333, test acc:0.5539 ===
# train loss:1.1428821980712427
# train loss:1.079324732920375
# train loss:1.0252772873400673
# === epoch:299, train acc:0.6733333333333333, test acc:0.5541 ===
# train loss:1.0675948420234915
# train loss:1.198105074762407
# train loss:1.0718790662669455
# === epoch:300, train acc:0.6733333333333333, test acc:0.5534 ===
# train loss:1.1532743891722048
# train loss:1.1815812615182575
# train loss:1.1595961452927641
# === epoch:301, train acc:0.6766666666666666, test acc:0.5549 ===
# train loss:1.1245057254525461
# train loss:1.1338249457108416
# =============== Final Test Accuracy ===============
# test acc:0.5559

# %%
# p.198 6.5.1 検証データ

from util import shuffle_dataset

(x_train, t_train), (x_test, t_test) = load_mnist()

# 訓練データをシャッフル
x_train, t_train = shuffle_dataset(x_train, t_train)

# 検証データの分割
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)

x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

print(x_val.shape)
print(t_val.shape)
print(x_train.shape)
print(t_train.shape)
# Out:
# (12000, 784)
# (12000,)
# (48000, 784)
# (48000,)

# %%
import numpy as np
import matplotlib.pyplot as plt
from mnist import load_mnist
from multi_layer_net import MultiLayerNet
from util import shuffle_dataset
from trainer import Trainer

(x_train, t_train), (x_test, t_test) = load_mnist(normalize=True)

# 高速化のための訓練データの削減
x_train = x_train[:500]
t_train = t_train[:500]

# 検証データの分離
validation_rate = 0.20
validation_num = int(x_train.shape[0] * validation_rate)
x_train, t_train = shuffle_dataset(x_train, t_train)
x_val = x_train[:validation_num]
t_val = t_train[:validation_num]
x_train = x_train[validation_num:]
t_train = t_train[validation_num:]

def __train(lr, weight_decay, epocs=50):
    network = MultiLayerNet(input_size=784, hidden_size_list=[100, 100, 100, 100, 100, 100],
                           output_size=10,
                           weight_decay_lambda=weight_decay)
    trainer = Trainer(network, x_train, t_train, x_val, t_val,
                     epochs=epocs, mini_batch_size=100,
                     optimizer='sgd', optimizer_param={'lr': lr},
                     verbose=False)
    trainer.train()
    
    return trainer.test_acc_list, trainer.train_acc_list

# ハイパーパラメータのランダム探索
optimazation_trial = 100
results_val = {}
results_train = {}

for _ in range(optimazation_trial):
    # 探索したハイパーパラメータの範囲を指定
    weight_decay = 10 ** np.random.uniform(-8, -4)
    lr = 10 ** np.random.uniform(-6, -2)
    
    val_acc_list, train_acc_list = __train(lr, weight_decay)
    print("val acc:" + str(val_acc_list[-1]) + " | lr:" + str(lr) + ", weight decay:" + str(weight_decay))
    key = "lr:" + str(lr) + ", weight decay:" + str(weight_decay)
    results_val[key] = val_acc_list
    results_train[key] = train_acc_list
    
# グラフの描画
print("=========== Hyper-Parameter Optimization Result ===========")
graph_draw_num = 20
col_num = 5
row_num = int(np.ceil(graph_draw_num / col_num))
i = 0

for key, val_acc_list in sorted(results_val.items(), key=lambda x:x[1][-1], reverse=True):
    print("Best-" + str(i+1) + "(val acc:" + str(val_acc_list[-1]) + ") | " + key)
    
    plt.subplot(row_num, col_num, i+1)
    plt.title("Best-" + str(i+1))
    plt.ylim(0.0, 1.0)
    if i % 5: plt.yticks([])
    plt.xticks([])
    x = np.arange(len(val_acc_list))
    plt.plot(x, val_acc_list)
    plt.plot(x, results_train[key], "--")
    i += 1
    
    if i >= graph_draw_num:
        break
        
plt.show()
# Out:
# val acc:0.43 | lr:0.003013457959049158, weight decay:2.7946836006572698e-05
# val acc:0.18 | lr:8.685083323949363e-05, weight decay:1.559388608951387e-05
# val acc:0.08 | lr:4.6988339479038486e-05, weight decay:1.8535333780055564e-06
# val acc:0.04 | lr:2.4029005787974583e-06, weight decay:6.237293930768876e-05
# val acc:0.07 | lr:1.282130057823122e-05, weight decay:4.308097427161638e-05
# val acc:0.07 | lr:2.746487952287671e-06, weight decay:9.154143462767271e-06
# val acc:0.17 | lr:0.0009037595086167808, weight decay:1.9739095515165153e-07
# val acc:0.58 | lr:0.004288451377278723, weight decay:4.6894408571891145e-05
# val acc:0.11 | lr:0.0005400163369358364, weight decay:1.7669646735691927e-05
# val acc:0.63 | lr:0.00361591640465638, weight decay:4.8954886942617355e-06
# val acc:0.59 | lr:0.0032401765759439, weight decay:7.03796434028644e-05
# val acc:0.14 | lr:6.43444584963547e-06, weight decay:1.2600348165779117e-07
# val acc:0.11 | lr:4.110056896688545e-05, weight decay:2.369183284634655e-05
# val acc:0.14 | lr:5.9652386753523756e-05, weight decay:2.6909590658642664e-08
# val acc:0.35 | lr:0.0027453327099654125, weight decay:6.460008439337449e-05
# val acc:0.14 | lr:4.100046349246675e-06, weight decay:7.394431748057633e-08
# val acc:0.08 | lr:0.00014166772112296722, weight decay:1.9890830687323868e-06
# val acc:0.77 | lr:0.00933368928138775, weight decay:1.4923816850756945e-06
# val acc:0.12 | lr:1.0367461961740887e-05, weight decay:1.5133941722701827e-05
# val acc:0.45 | lr:0.0030141324162536545, weight decay:5.697042320421514e-06
# val acc:0.2 | lr:0.0009040111675147647, weight decay:5.641408814567329e-05
# val acc:0.12 | lr:0.0009002915320258169, weight decay:6.910022791219483e-07
# val acc:0.12 | lr:7.653043535441615e-05, weight decay:1.6387391348986248e-06
# val acc:0.12 | lr:0.0005991000094871499, weight decay:1.2008677479819227e-08
# val acc:0.09 | lr:7.258419094813824e-05, weight decay:3.68200387523754e-05
# val acc:0.14 | lr:2.732134669956014e-06, weight decay:2.6616523108400706e-05
# val acc:0.11 | lr:0.0002356264301208732, weight decay:6.629442120525633e-07
# val acc:0.13 | lr:5.216659152399634e-05, weight decay:1.8214551429335978e-06
# val acc:0.58 | lr:0.0028704018456581714, weight decay:2.977275527471933e-07
# val acc:0.12 | lr:6.117656668215874e-06, weight decay:2.364721205253188e-06
# val acc:0.12 | lr:4.262189852659819e-05, weight decay:1.4061944026199203e-06
# val acc:0.69 | lr:0.006101178103321245, weight decay:1.790152364323267e-05
# val acc:0.23 | lr:0.0007852542326663091, weight decay:4.365736397358779e-07
# val acc:0.08 | lr:0.0006010984683523386, weight decay:7.225418774483262e-08
# val acc:0.11 | lr:0.0010372398479555009, weight decay:6.477942210273178e-06
# val acc:0.07 | lr:5.783189069368236e-06, weight decay:1.8507150079394105e-08
# val acc:0.14 | lr:0.0014470563497844201, weight decay:1.9412383484895333e-07
# val acc:0.05 | lr:2.4246809626602165e-05, weight decay:5.807967999700724e-05
# val acc:0.05 | lr:1.5912284142093497e-05, weight decay:3.6583635415110936e-07
# val acc:0.69 | lr:0.00622171473861624, weight decay:4.3911913837788644e-05
# val acc:0.05 | lr:1.0403177448887e-06, weight decay:1.970562796830074e-05
# val acc:0.1 | lr:0.0002816914721348626, weight decay:2.661824902255171e-06
# val acc:0.11 | lr:4.784408935479658e-06, weight decay:5.624423167809176e-05
# val acc:0.07 | lr:2.115021038283649e-06, weight decay:4.443440204770008e-05
# val acc:0.11 | lr:0.0002947450314798972, weight decay:9.129093145690115e-06
# val acc:0.13 | lr:4.275999949182045e-05, weight decay:7.577957769227688e-06
# val acc:0.15 | lr:0.00011738999742649454, weight decay:1.2370357439379414e-07
# val acc:0.09 | lr:4.385140895133287e-05, weight decay:8.138704216760527e-06
# val acc:0.14 | lr:0.0005741812947666397, weight decay:8.171483417350151e-06
# val acc:0.07 | lr:8.888410479005275e-06, weight decay:5.62400691891171e-07
# val acc:0.14 | lr:5.199588627402398e-05, weight decay:2.778736701171587e-08
# val acc:0.48 | lr:0.0027732043661959777, weight decay:1.409429081089549e-08
# val acc:0.04 | lr:0.0005448631659169923, weight decay:1.7773500135568231e-06
# val acc:0.12 | lr:2.2688835600401125e-05, weight decay:3.71631922982699e-05
# val acc:0.47 | lr:0.003691135816420422, weight decay:7.536041521583492e-05
# val acc:0.05 | lr:3.276978491723682e-06, weight decay:2.6969075724015e-05
# val acc:0.57 | lr:0.0031043885674098878, weight decay:1.7469779983743173e-07
# val acc:0.62 | lr:0.006543405765196358, weight decay:5.574846067414844e-08
# val acc:0.11 | lr:7.774016770969029e-06, weight decay:5.229229109503035e-05
# val acc:0.85 | lr:0.009844414032223737, weight decay:3.4826101908204724e-06
# val acc:0.13 | lr:5.713975298579847e-06, weight decay:9.597774051491773e-07
# val acc:0.12 | lr:4.073980169522733e-06, weight decay:1.529160415463418e-06
# val acc:0.1 | lr:0.00026312536952186234, weight decay:1.241204175563318e-06
# val acc:0.05 | lr:3.1086598893983474e-06, weight decay:3.732704762782303e-05
# val acc:0.13 | lr:0.0004260468823963389, weight decay:8.416410861509454e-05
# val acc:0.1 | lr:0.00012716033637222998, weight decay:4.36651769152476e-08
# val acc:0.11 | lr:0.00010840850258648623, weight decay:1.9007511562931479e-06
# val acc:0.13 | lr:0.00010234752387504839, weight decay:9.499047524360985e-07
# val acc:0.79 | lr:0.0068318889508686585, weight decay:1.4170901985687756e-06
# val acc:0.07 | lr:3.2391405929918225e-06, weight decay:1.7739509722283433e-06
# val acc:0.13 | lr:0.00031508712791228246, weight decay:8.556550614083512e-06
# val acc:0.09 | lr:0.00022125632767780543, weight decay:6.053232445403137e-05
# val acc:0.67 | lr:0.004454298269415494, weight decay:7.273666935493538e-07
# val acc:0.08 | lr:5.635087380067045e-06, weight decay:3.007025622914909e-08
# val acc:0.14 | lr:2.8391886083682386e-05, weight decay:1.879639139134844e-07
# val acc:0.04 | lr:7.8591512593044e-06, weight decay:4.6951170472840164e-08
# val acc:0.29 | lr:0.0009031537753571506, weight decay:5.4548887493985685e-08
# val acc:0.09 | lr:1.1684906713081819e-05, weight decay:1.3000041556715376e-05
# val acc:0.12 | lr:1.4242091783199776e-06, weight decay:1.9188607526069994e-06
# val acc:0.57 | lr:0.0033390822350699728, weight decay:3.7373828333555987e-06
# val acc:0.02 | lr:6.886566590809547e-05, weight decay:6.646562078945544e-07
# val acc:0.21 | lr:9.587896045943721e-05, weight decay:8.959455684636659e-07
# val acc:0.77 | lr:0.009384681008345969, weight decay:3.509803283855619e-05
# val acc:0.12 | lr:0.0008866596168770013, weight decay:6.2026383686434e-07
# val acc:0.16 | lr:1.4869339328829368e-05, weight decay:1.5853511930725796e-05
# val acc:0.14 | lr:0.0006307394262217215, weight decay:1.2058140189258277e-06
# val acc:0.09 | lr:6.186197270420191e-06, weight decay:1.151583679736102e-06
# val acc:0.08 | lr:5.298704188766739e-06, weight decay:2.433132470078706e-07
# val acc:0.07 | lr:1.5658486695014238e-05, weight decay:1.8577711312861014e-05
# val acc:0.05 | lr:1.3319557383308355e-06, weight decay:4.6483163940566264e-05
# val acc:0.24 | lr:0.001716564483839859, weight decay:4.850683980624619e-07
# val acc:0.18 | lr:0.0006480998278849684, weight decay:1.1612014296546178e-08
# val acc:0.1 | lr:0.0011902601012631143, weight decay:8.501801682527307e-07
# val acc:0.09 | lr:7.05665124927585e-06, weight decay:3.8262929024104315e-06
# val acc:0.38 | lr:0.00229461741297744, weight decay:2.2032440212649782e-05
# val acc:0.12 | lr:1.1596258647812906e-06, weight decay:9.682243078091234e-07
# val acc:0.12 | lr:2.2341782559450673e-05, weight decay:1.0925306964286058e-07
# val acc:0.78 | lr:0.007120680377347303, weight decay:1.0694164176498248e-07
# val acc:0.15 | lr:5.088136352446917e-05, weight decay:2.216892250348351e-07
# val acc:0.13 | lr:0.0003529326821419029, weight decay:1.1293643209154395e-08
# =========== Hyper-Parameter Optimization Result ===========
# Best-1(val acc:0.85) | lr:0.009844414032223737, weight decay:3.4826101908204724e-06
# Best-2(val acc:0.79) | lr:0.0068318889508686585, weight decay:1.4170901985687756e-06
# Best-3(val acc:0.78) | lr:0.007120680377347303, weight decay:1.0694164176498248e-07
# Best-4(val acc:0.77) | lr:0.00933368928138775, weight decay:1.4923816850756945e-06
# Best-5(val acc:0.77) | lr:0.009384681008345969, weight decay:3.509803283855619e-05
# Best-6(val acc:0.69) | lr:0.006101178103321245, weight decay:1.790152364323267e-05
# Best-7(val acc:0.69) | lr:0.00622171473861624, weight decay:4.3911913837788644e-05
# Best-8(val acc:0.67) | lr:0.004454298269415494, weight decay:7.273666935493538e-07
# Best-9(val acc:0.63) | lr:0.00361591640465638, weight decay:4.8954886942617355e-06
# Best-10(val acc:0.62) | lr:0.006543405765196358, weight decay:5.574846067414844e-08
# Best-11(val acc:0.59) | lr:0.0032401765759439, weight decay:7.03796434028644e-05
# Best-12(val acc:0.58) | lr:0.004288451377278723, weight decay:4.6894408571891145e-05
# Best-13(val acc:0.58) | lr:0.0028704018456581714, weight decay:2.977275527471933e-07
# Best-14(val acc:0.57) | lr:0.0031043885674098878, weight decay:1.7469779983743173e-07
# Best-15(val acc:0.57) | lr:0.0033390822350699728, weight decay:3.7373828333555987e-06
# Best-16(val acc:0.48) | lr:0.0027732043661959777, weight decay:1.409429081089549e-08
# Best-17(val acc:0.47) | lr:0.003691135816420422, weight decay:7.536041521583492e-05
# Best-18(val acc:0.45) | lr:0.0030141324162536545, weight decay:5.697042320421514e-06
# Best-19(val acc:0.43) | lr:0.003013457959049158, weight decay:2.7946836006572698e-05
# Best-20(val acc:0.38) | lr:0.00229461741297744, weight decay:2.2032440212649782e-05
